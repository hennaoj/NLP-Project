# %%
import math
from nltk.corpus.reader.bnc import BNCCorpusReader
from nltk import FreqDist
import matplotlib.pyplot as plt
import re
import pickle
import nltk

# %%
#Data structure for storing info of a collocate word
class CollocateWord:
    
    def __init__(self, collocate):
        self.collocate = collocate
        #Frequency of how often collocate word is found with word of interest
        self.collocateFrequency = 1
        #Will be calculated later with method call
        self.mutualInformation = None
        #Words count in corpus. Will be set later with method call
        self.corpusFrequency = None
        #Is the word positioned before of after the parent word in a sentence
        self.position = None #Not used yet

    def getWord(self):
        return self.collocate

    #Called in main each time the same word is found again
    def updateFrequency(self):
        self.collocateFrequency += 1

    def printMe(self):
        print("Collocate word: " + self.collocate)
        print("Frequency with parent word: " + str(self.collocateFrequency))
        print("Frequency in corpus: " + str(self.corpusFrequency))
        print("MI score: " + str(self.mutualInformation))

    def setMutualInformation(self, MI):
        self.mutualInformation = MI

    def setCorpusFrequency(self, freq):
        self.corpusFrequency = freq

# %%
#Data structure and logic for word under search and its collocates
class MutualInformationCalculator:
    
    def __init__(self, word, corpusSentences, corpusWords, span, sizeOfCorpus, freqDistribution):
        self.word = word
        self.frequency = 0
        self.collocates = []
        self.corpusSentences = corpusSentences
        self.corpusWords = corpusWords
        self.span = span
        self.sizeOfCorpus = sizeOfCorpus
        self.freqDistribution = freqDistribution

    def findCollocates(self):
        '''Find all collocate words around the word of interest'''    
        for sentence in self.corpusSentences:
            l_sentence = [(word_tuple[0].lower(), word_tuple[1] )for word_tuple in sentence]
            #if(l_sentence[0].count(self.word) == 0):
            #    continue
            #Should we remove stop words from search? Should be done here, at latest.
            for index, word in enumerate(l_sentence):
                #print(word[0].lower())
                #print(index)
                if word[0] == self.word:
                    self.updateFrequency()
                    self.findSpanningCollocations(l_sentence, index)
    
    def findSpanningCollocations(self, sentence, startingIndex,):
        '''When words of interest is found in the sentence, the sentence and index is passed here to find collocate words
        and updateCollocates is called for valid words to save them'''
        listOfIndexes = []
        #Assuming that the span = 4 in the task description actually means windows size instead, check only adjacent indexes.
        #  CURRENTLY FIXED WINDOW SIZE = 5
        indexesToTry = [startingIndex - 2, startingIndex - 1, startingIndex + 1, startingIndex + 2]
        for index in indexesToTry:
            if index >= 0 and index < len(sentence):
                word, wordType = sentence[index]
                #program should indentify only adjectives, adverbs and verbs
                if wordType == 'ADJ' or wordType == 'ADV' or wordType == "VERB":
                    self.updateCollocates(word)

    def updateCollocates(self, collocateWord):
        '''Checks if collocate is new to append it to list or to just update existing frequency'''
        #Check if collocate list is empty
        if self.collocates:
            for collocate in self.collocates:
                if collocate.getWord() == collocateWord:
                    collocate.updateFrequency()
                    return
                    
            self.collocates.append(CollocateWord(collocateWord))
        else:
            self.collocates.append(CollocateWord(collocateWord))
    
    #Used while searching collocate words.
    def updateFrequency(self):
        self.frequency += 1

    def calculateCollocateFrequencies(self):
        #Set the frequency in corpus for every collocate word
        for collocate in self.collocates:
            collocate.setCorpusFrequency(self.freqDistribution[collocate.getWord()])
            

    def printMe(self):
        print("Word of interest: " + self.word)
        print("Frequncy in corpus: " + str(self.frequency))
        print("Collocate words found: " + str(len(self.collocates)))

    def printCollocates(self):
        for collocate in self.collocates:
            collocate.printMe()

    def getCollocates(self):
        return self.collocates

    def calculateMutualInformations(self):
        '''Calculate MI for all collocate words. Requires that frequencies are calculated before running this.'''
        for collocate in self.collocates:
            MI = math.log10(( (collocate.collocateFrequency * self.sizeOfCorpus) / (self.frequency * collocate.corpusFrequency * self.span) ))
            MI = MI / math.log10(2)
            collocate.setMutualInformation(MI)

    def calculateAll(self):
        '''Does all calculation steps in one command.'''
        self.findCollocates()
        self.calculateCollocateFrequencies()
        self.calculateMutualInformations()
        self.removeCollocatesBelowFrequency(2)
        self.removeCollocatesBelowMI(3)

    def getCollacatesOverMiValue(self, limit):
        '''Return a list of collocates above wanted MI value'''
        return [collocate for collocate in self.collocates if (collocate.mutualInformation >= limit)]

    def getCollocatesOverFrequency(self, limit):
        return [collocate for collocate in self.collocates if (collocate.collocateFrequency >= limit)]

    def removeCollocatesBelowFrequency(self, limitFrequency):
        '''Remove collocates from object whose frequency with word of interest is lower than given limit.'''
        self.collocates[:] = [collocate for collocate in self.collocates if (collocate.collocateFrequency >= limitFrequency)]

    def removeCollocatesBelowMI(self, limitMI):
        self.collocates[:] = [collocate for collocate in self.collocates if (collocate.mutualInformation >= limitMI)]

    def sortCollocatesByFrequency(self):
        self.collocates.sort(key=lambda collocate: collocate.collocateFrequency, reverse=True)

    def sortCollocatesByMIscore(self):
        self.collocates.sort(key=lambda collocate: collocate.mutualInformation, reverse=True)

    def plotFrequencyFigure(self, xSize, ySize):
        miLim = 3
        fLim = 2
        #self.sortCollocatesByFrequency()
        words = [c.collocate for c in self.collocates]
        freqs = [c.collocateFrequency for c in self.collocates]
        fig, ax = plt.subplots(figsize = (xSize, ySize))
        ax.set_ylabel('Mutual frequency', fontsize=15)
        ax.set_title('Frequency of adjacent words from \'' + self.word + '\' with MI score >= ' + str(miLim) + ' and mutual frequency >= ' + str(fLim) + ')')
        ax.barh(words, freqs)
        plt.show()

    def plotMiFigure(self, xSize, ySize):
        miLim = 3
        fLim = 2
        self.sortCollocatesByMIscore()
        words = [c.collocate for c in self.collocates]
        mi_score = [c.mutualInformation for c in self.collocates]
        fig, ax = plt.subplots(figsize = (xSize, ySize))
        ax.set_ylabel('Mutual Information score', fontsize=15)
        ax.set_title('Mutual information score over ' + str(miLim) + ' with a word \'' + self.word + '\' and mutual frequency >= ' + str(fLim) + ')')
        ax.barh(words, mi_score)
        plt.show()

    def plotPresentationFigures(self):
        '''Plots only 25 top MI collocates, removes others'''
        self.collocates = self.collocates[:25]
        self.plotMiFigure(5,5)
        self.plotFrequencyFigure(5,5)

# %%
with open('sentsA.pkl', 'rb') as input:
    corpusSentences = pickle.load(input)

# %%
with open('wordsA.pkl', 'rb') as input:
    corpusWords = pickle.load(input)
#We want decapitalize words for easier handling
lower_words = [word.lower() for word in corpusWords]
sizeOfCorpus = len(lower_words)

# %%
#Test with task 9 corpus
'''from nltk.corpus import reuters
sents_without_tags = list(reuters.sents())
corpusSentences = []

for sentence in sents_without_tags:
    tagged_words = nltk.pos_tag(sentence)
    corpusSentences.append(tagged_words)
words = list(reuters.words())
lower_words = [word.lower() for word in words]
sizeOfCorpus = len(lower_words)'''

# %%
#Calculate frequencies for all the words in corpus
fdist = FreqDist(lower_words)

# %%
'''
Formatting of the metaphor annotated corpus: http://aclweb.org/anthology/W/W17/W17-2201.pdf
Example: destroying alexandria . sunlight is silence @4@y
@-sign separates different fields
Sentece:                        destroying alexandria . sunlight is silence
Position of the head word       4 -> sunlight
Is the expression a metaphore?  y (yes), n (no), s (skipped)
'''
annotatedSentences = []
headWordPosition = []
isSentenceMetaphor = []
with open("type1_metaphor_annotated.txt") as textfile:
    for line in textfile: 
        line = line.split("@")
        if(line[2].strip() != 's'): #Exclude sentences which humans failed to classify
            annotatedSentences.append(line[0].strip())
            headWordPosition.append(line[1].strip())
            isSentenceMetaphor.append(line[2].strip())

'''
The dataset is quite problematic because the text is so unclean:
(
the night is each man 's castle . @2@y
swelling lukewarm ; her mouth is water , @5@y
& yet the earth is divinity , the sky is divinity @4@n
"i am the resurrection and the life . " @1@n
"how is the dean ? " -- "he 's just alive . " @1@n <-- especially problematic, because quotation mark is connected to the word
)
If all special characters are cleaned a way, the head word
position tag may change, and we cannot reliably verify the algorithm.
If not cleaned, the some words are left unrecognized...
'''
# Out:
# '\nThe dataset is quite problematic because the text is so unclean:\n(\nthe night is each man \'s castle . @2@y\nswelling lukewarm ; her mouth is water , @5@y\n& yet the earth is divinity , the sky is divinity @4@n\n"i am the resurrection and the life . " @1@n\n"how is the dean ? " -- "he \'s just alive . " @1@n <-- especially problematic, because quotation mark is connected to the word\n)\nIf all special characters are cleaned a way, the head word\nposition tag may change, and we cannot reliably verify the algorithm.\nIf not cleaned, the some words are left unrecognized...\n'

# %%
def getCollocatesAroundHead(sentence, index, span):
    taggedSentence = nltk.pos_tag(sentence, 'universal')
    width = span / 2
    print(taggedSentence)
    collocates = []
    i = 1
    while(width > 0):
        if(index - i >= 0):
            if(taggedSentence[index -i][1] in {'ADJ','ADV', 'VERB'} and (taggedSentence[index -i][1] != '')):
                collocates.append(sentence[index -i])
        
        if(index + i <= len(sentence)):
            if(taggedSentence[index +i][1] in {'ADJ','ADV', 'VERB'} and (taggedSentence[index -i][1] != '')):
                collocates.append(sentence[index + i])
        i +=1
        width -= 1
    print("collocates around head in sentence:", collocates)
    
    
    return collocates

# %%
span = 4

# %%
predictions = []
for i in range(len(headWordPosition)):
    #print(annotatedSentences[i])
    sentence = annotatedSentences[i].split()
    headWordIndex =int(headWordPosition[i])-1
    
    
    sentence = [re.sub(r'[^a-zA-Z ]', '', word) for word in sentence]
    sentence[:] = [word.strip() for word in sentence]
    headWord = sentence[headWordIndex].lower()
    #sentence[:] = [word for word in sentence if word] #this will mess up the head word indexing
    #print(sentence)
    print(headWord)

    MutualInformation = MutualInformationCalculator(headWord, corpusSentences, lower_words, span, sizeOfCorpus, fdist)
    MutualInformation.findCollocates()
    MutualInformation.calculateCollocateFrequencies()
    MutualInformation.calculateMutualInformations()
    #TODO: select frequency cutoff
    #MutualInformation.printMe()

    corpusCollocates = MutualInformation.getCollocates()

    #TODO: get only adj, adv, verb?
    sentenceCollocates = getCollocatesAroundHead(sentence, headWordIndex, span)
    
    matchingCollocates = []
    for collocate in sentenceCollocates:
        for corpCollocate in corpusCollocates:
            if collocate == corpCollocate.getWord():
                matchingCollocates.append(corpCollocate)

    for c in matchingCollocates:
        print(c.collocate, c.mutualInformation)
    print('\n')
    isMetaphor = False
    
    for c in matchingCollocates:
        if c.mutualInformation < 2.5:
            isMetaphor = True
    if not matchingCollocates:
        predictions.append('u')
    elif isMetaphor == False:
        predictions.append('n')
    else:
        predictions.append('y')
# Out:
# poise
# [('poise', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('club', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.038609601491496164
#
#
# sunlight
# [('destroying', 'VERB'), ('alexandria', 'NOUN'), ('', 'ADJ'), ('sunlight', 'NOUN'), ('is', 'VERB'), ('silence', 'NOUN')]
# collocates around head in sentence: ['', 'is']
# is -0.3275182973064011
#
#
# feet
# [('feet', 'NOUN'), ('are', 'VERB'), ('no', 'DET'), ('anchor', 'NOUN'), ('', 'VERB'), ('gravity', 'NOUN'), ('sucks', 'NOUN'), ('at', 'ADP'), ('the', 'DET'), ('mind', 'NOUN')]
# collocates around head in sentence: ['are']
# are -0.009480457976587938
#
#
# horizon
# [('on', 'ADP'), ('the', 'DET'), ('day', 'NOUN'), ('s', 'VERB'), ('horizon', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('gesture', 'NOUN'), ('of', 'ADP'), ('earth', 'NOUN')]
# collocates around head in sentence: ['s', 'is']
# is 1.1305320909325356
#
#
# goodby
# [('he', 'PRON'), ('said', 'VERB'), ('goodby', 'NOUN'), ('as', 'ADP'), ('if', 'ADP'), ('goodby', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('number', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
#
#
# eyes
# [('although', 'ADP'), ('your', 'PRON'), ('eyes', 'NOUN'), ('be', 'VERB'), ('lakes', 'NOUN'), ('', 'ADJ'), ('dies', 'NOUN')]
# collocates around head in sentence: ['be']
# be -3.3223838248483903
#
#
# world
# [('ways', 'NOUN'), ('', 'VERB'), ('as', 'ADP'), ('if', 'ADP'), ('the', 'DET'), ('world', 'NOUN'), ('were', 'VERB'), ('a', 'DET'), ('taxi', 'NOUN'), ('', 'NOUN'), ('you', 'PRON'), ('enter', 'VERB'), ('it', 'PRON'), ('', 'VERB'), ('then', 'ADV')]
# collocates around head in sentence: ['were']
# were -1.6523237974985323
#
#
# poet
# [('the', 'DET'), ('poet', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('man', 'NOUN'), ('who', 'PRON'), ('feigns', 'VERB')]
# collocates around head in sentence: ['is']
# is -0.40444227395694404
#
#
# man
# [('man', 'NOUN'), ('is', 'VERB'), ('an', 'DET'), ('animal', 'NOUN'), ('that', 'DET'), ('needs', 'VERB'), ('a', 'DET'), ('warden', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.17024889347957267
#
#
# name
# [('my', 'PRON'), ('name', 'NOUN'), ('is', 'VERB'), ('james', 'VERB'), ('a', 'DET'), ('', 'ADJ'), ('wright', 'NOUN'), ('', 'NOUN'), ('and', 'CONJ'), ('i', 'NOUN'), ('was', 'VERB'), ('born', 'VERB')]
# collocates around head in sentence: ['is', 'james']
# is 0.7423927627069589
#
#
# earth
# [('earth', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('door', 'NOUN'), ('i', 'NOUN'), ('cannot', 'VERB'), ('even', 'ADV'), ('face', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.027962357291987656
#
#
# neck
# [('the', 'DET'), ('hackles', 'NOUN'), ('on', 'ADP'), ('my', 'PRON'), ('neck', 'NOUN'), ('are', 'VERB'), ('fear', 'ADJ'), ('', 'ADP'), ('not', 'ADV'), ('grief', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['are', 'fear']
# are -0.6258825835561681
#
#
# moon
# [('the', 'DET'), ('moon', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('sow', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.6732025154463716
#
#
# earth
# [('earth', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('birth', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('blues', 'NOUN'), ('', 'VERB'), ('', 'NOUN'), ('sang', 'VERB'), ('yellow', 'ADJ'), ('bertha', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.027962357291987656
#
#
# one
# [('about', 'ADP'), ('the', 'DET'), ('nature', 'NOUN'), ('of', 'ADP'), ('understanding', 'VERB'), ('', 'ADJ'), ('no', 'DET'), ('one', 'NOUN'), ('is', 'VERB'), ('that', 'ADP'), ('simple', 'ADJ')]
# collocates around head in sentence: ['is', '']
# is 1.0539315547757258
#
#
# nature
# [('the', 'DET'), ('real', 'ADJ'), ('terror', 'NOUN'), ('of', 'ADP'), ('nature', 'NOUN'), ('is', 'VERB'), ('humanity', 'NOUN'), ('enraged', 'VERB'), ('', 'DET'), ('the', 'DET'), ('true', 'ADJ')]
# collocates around head in sentence: ['is']
# is 0.22945157046182904
#
#
# love
# [('love', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('word', 'NOUN'), ('another', 'DET'), ('kind', 'NOUN'), ('of', 'ADP'), ('open', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.09653005431990357
#
#
# goodbye
# [('your', 'PRON'), ('goodbye', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('promise', 'NOUN'), ('of', 'ADP'), ('lightning', 'VERB')]
# collocates around head in sentence: ['is']
# is -3.119392232574997
#
#
# body
# [('his', 'PRON'), ('broken', 'NOUN'), ('body', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('afterimage', 'NOUN'), ('of', 'ADP'), ('my', 'PRON'), ('st', 'ADJ'), ('year', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.45808207211068164
#
#
# eyes
# [('my', 'PRON'), ('eyes', 'NOUN'), ('are', 'VERB'), ('caves', 'NOUN'), ('', 'ADJ'), ('chunks', 'NOUN'), ('of', 'ADP'), ('etched', 'ADJ'), ('rock', 'NOUN')]
# collocates around head in sentence: ['are']
# are 0.47612181488044686
#
#
# sky
# [('the', 'DET'), ('sky', 'NOUN'), ('is', 'VERB'), ('baby', 'ADJ'), ('blue', 'ADJ'), ('', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('justunfurling', 'NOUN'), ('leaves', 'NOUN')]
# collocates around head in sentence: ['is', 'baby']
# is 0.11425969824394078
#
#
# road
# [('down', 'ADP'), ('the', 'DET'), ('road', 'NOUN'), ('is', 'VERB'), ('somebody', 'ADJ'), ('small', 'ADJ'), ('on', 'ADP'), ('the', 'DET'), ('shoulder', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'somebody']
# is -0.7614615276071368
#
#
# life
# [('i', 'NOUN'), ('wrote', 'VERB'), ('life', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('strain', 'NOUN'), ('', 'NOUN'), ('later', 'ADV'), ('', 'NOUN'), ('someone', 'NOUN'), ('crossed', 'VERB'), ('it', 'PRON'), ('out', 'PRT'), ('', 'NOUN')]
# collocates around head in sentence: ['wrote', 'was']
# wrote -0.726241554446722
# was -0.07636651185532756
#
#
# haggard
# [('it', 'PRON'), ('is', 'VERB'), ('clear', 'ADJ'), ('that', 'ADP'), ('mr', 'NOUN'), ('', 'NOUN'), ('haggard', 'NOUN'), ('is', 'VERB'), ('ryder', 'ADJ'), ('s', 'ADJ'), ('brother', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'ryder']
#
#
# mind
# [('the', 'DET'), ('mind', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('city', 'NOUN'), ('like', 'ADP'), ('london', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.24302877237014908
#
#
# others
# [('', 'VERB'), ('the', 'DET'), ('others', 'NOUN'), ('were', 'VERB'), ('the', 'DET'), ('despots', 'NOUN'), ('of', 'ADP'), ('despair', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['were', '']
# were 1.9142012844184813
#
#
# humor
# [('knowing', 'VERB'), ('intuitively', 'ADV'), ('how', 'ADV'), ('a', 'DET'), ('sense', 'NOUN'), ('of', 'ADP'), ('humor', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('necessity', 'NOUN')]
# collocates around head in sentence: ['was']
#
#
# name
# [('your', 'PRON'), ('guilt', 'NOUN'), ('is', 'VERB'), ('nameless', 'ADJ'), ('', 'ADV'), ('because', 'ADP'), ('its', 'PRON'), ('name', 'NOUN'), ('is', 'VERB'), ('time', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.7423927627069589
#
#
# name
# [('because', 'ADP'), ('its', 'PRON'), ('name', 'NOUN'), ('is', 'VERB'), ('death', 'NOUN'), ('', 'NOUN'), ('but', 'CONJ'), ('you', 'PRON'), ('can', 'VERB'), ('stop', 'VERB')]
# collocates around head in sentence: ['is']
# is 0.7423927627069589
#
#
# hamlet
# [('hamlet', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('example', 'NOUN'), ('', 'NOUN'), ('only', 'ADV'), ('dying', 'VERB')]
# collocates around head in sentence: ['is']
# is -0.2833184933958661
#
#
# sun
# [('the', 'DET'), ('sun', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('yellowjacket', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.24763935229275663
#
#
# love
# [('love', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('fiction', 'NOUN'), ('i', 'NOUN'), ('must', 'VERB'), ('use', 'VERB'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.09653005431990357
#
#
# people
# [('and', 'CONJ'), ('people', 'NOUN'), ('are', 'VERB'), ('home', 'NOUN'), ('for', 'ADP'), ('the', 'DET'), ('homecomings', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['are']
# are 1.8922755270734328
#
#
# life
# [('yet', 'ADV'), ('life', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('invocation', 'NOUN'), ('sealed', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('coffin', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['yet', 'is']
# yet -1.013897420085383
# is 0.45217928334522717
#
#
# darkness
# [('this', 'DET'), ('swift', 'ADJ'), ('darkness', 'NOUN'), ('is', 'VERB'), ('spring', 'VERB'), ('s', 'NOUN'), ('first', 'ADV'), ('hour', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['swift', 'is', 'spring']
# is -1.0891459457068764
#
#
# trees
# [('the', 'DET'), ('trees', 'NOUN'), ('are', 'VERB'), ('crystal', 'ADJ'), ('chandeliers', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['are', 'crystal']
# are 0.827168241659407
#
#
# branches
# [('but', 'CONJ'), ('still', 'ADV'), ('the', 'DET'), ('branches', 'NOUN'), ('are', 'VERB'), ('wire', 'NOUN')]
# collocates around head in sentence: ['are', 'still']
# are 0.02904724174402657
# still -0.7647432702687741
#
#
# deer
# [('the', 'DET'), ('deer', 'NOUN'), ('are', 'VERB'), ('ghosts', 'NOUN'), ('who', 'PRON'), ('slip', 'VERB'), ('between', 'ADP'), ('the', 'DET'), ('light', 'NOUN')]
# collocates around head in sentence: ['are']
# are -1.686003575993739
#
#
# cemetery
# [('the', 'DET'), ('gray', 'NOUN'), ('snow', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('cemetery', 'NOUN'), ('was', 'VERB'), ('sheet', 'ADJ'), ('tin', 'NOUN'), ('', 'ADP'), ('if', 'ADP'), ('i', 'NOUN'), ('said', 'VERB')]
# collocates around head in sentence: ['was', 'sheet']
# was 0.6097931496801693
#
#
# spades
# [('and', 'CONJ'), ('spades', 'NOUN'), ('are', 'VERB'), ('spades', 'NOUN'), ('and', 'CONJ'), ('clubs', 'NOUN'), ('are', 'VERB'), ('clovers', 'NOUN'), ('black', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['are']
# are 2.3437437674003134
#
#
# clubs
# [('and', 'CONJ'), ('spades', 'NOUN'), ('are', 'VERB'), ('spades', 'NOUN'), ('and', 'CONJ'), ('clubs', 'NOUN'), ('are', 'VERB'), ('clovers', 'NOUN'), ('black', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['are']
# are 0.9362399408068768
#
#
# books
# [('the', 'DET'), ('lean', 'ADJ'), ('monkcopyist', 'NOUN'), ('who', 'PRON'), ('scribes', 'VERB'), ('the', 'DET'), ('books', 'NOUN'), ('is', 'VERB'), ('slateblue', 'ADJ'), ('at', 'ADP'), ('his', 'PRON'), ('fingertips', 'NOUN')]
# collocates around head in sentence: ['is', 'scribes', 'slateblue']
# is -1.4007125499107744
#
#
# talisman
# [('whose', 'PRON'), ('talisman', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('phoenix', 'NOUN')]
# collocates around head in sentence: ['is']
#
#
# emblem
# [('whose', 'PRON'), ('emblem', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('rock', 'NOUN'), ('of', 'ADP'), ('gibraltar', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is 1.500715354427119
#
#
# machines
# [('machines', 'NOUN'), ('are', 'VERB'), ('the', 'DET'), ('animals', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('americans', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['are']
# are 1.87167532308509
#
#
# man
# [('man', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('speech', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.17024889347957267
#
#
# books
# [('where', 'ADV'), ('books', 'NOUN'), ('were', 'VERB'), ('trees', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['where', 'were']
# where -1.8115856298454576
# were 1.4642497175853042
#
#
# trees
# [('where', 'ADV'), ('trees', 'NOUN'), ('were', 'VERB'), ('books', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['where', 'were']
# where -0.4558795969079866
# were 1.0521291926518086
#
#
# underwear
# [('underwear', 'NOUN'), ('is', 'VERB'), ('something', 'NOUN')]
# collocates around head in sentence: ['is']
# is -1.3150273531232044
#
#
# henry
# [('john', 'NOUN'), ('henry', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('man', 'NOUN'), ('just', 'ADV'), ('six', 'NUM'), ('feet', 'NOUN'), ('high', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['was']
# was 0.8079380247699401
#
#
# man
# [('', 'VERB'), ('a', 'DET'), ('man', 'NOUN'), ('is', 'VERB'), ('nothing', 'NOUN'), ('but', 'CONJ'), ('a', 'DET'), ('man', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is', '']
# is 0.17024889347957267
#
#
# heart
# [('his', 'PRON'), ('heart', 'NOUN'), ('was', 'VERB'), ('all', 'DET'), ('aflutter', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['was']
# was -0.23275961818465274
#
#
# words
# [('lifted', 'VERB'), ('', 'NOUN'), ('as', 'ADP'), ('we', 'PRON'), ('say', 'VERB'), ('', 'ADJ'), ('since', 'ADP'), ('words', 'NOUN'), ('are', 'VERB'), ('a', 'DET'), ('weight', 'ADJ'), ('', 'NOUN'), ('and', 'CONJ'), ('music', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['are', '']
# are 1.0701846340365155
#
#
# vapor
# [('in', 'ADP'), ('vapor', 'NOUN'), ('was', 'VERB'), ('the', 'DET'), ('ocean', 'ADJ'), ('s', 'NOUN'), ('presence', 'NOUN'), ('', 'NUM'), ('ghost', 'NOUN')]
# collocates around head in sentence: ['was']
#
#
# use
# [('what', 'PRON'), ('use', 'NOUN'), ('are', 'VERB'), ('books', 'NOUN'), ('to', 'PRT'), ('me', 'PRON')]
# collocates around head in sentence: ['are']
# are -2.0100891922470767
#
#
# god
# [('to', 'PRT'), ('them', 'PRON'), ('lead', 'VERB'), ('floats', 'NOUN'), ('', 'VERB'), ('a', 'DET'), ('leaf', 'ADJ'), ('sinks', 'NOUN'), ('', 'VERB'), ('their', 'PRON'), ('god', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('size', 'NOUN')]
# collocates around head in sentence: ['is', '']
# is 1.2078848866242964
#
#
# night
# [('the', 'DET'), ('night', 'NOUN'), ('is', 'VERB'), ('each', 'DET'), ('man', 'NOUN'), ('s', 'VERB'), ('castle', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -1.8835393330637662
#
#
# joy
# [('that', 'ADP'), ('all', 'DET'), ('recurring', 'VERB'), ('joy', 'NOUN'), ('is', 'VERB'), ('pain', 'ADJ'), ('refined', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['recurring', 'is', 'pain']
# is 0.6856063807068363
#
#
# sun
# [('in', 'ADP'), ('june', 'DET'), ('the', 'DET'), ('sun', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('bonnet', 'NOUN'), ('of', 'ADP'), ('light', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.24763935229275663
#
#
# afternoon
# [('this', 'DET'), ('afternoon', 'NOUN'), ('was', 'VERB'), ('the', 'DET'), ('colour', 'NOUN'), ('of', 'ADP'), ('water', 'NOUN'), ('falling', 'VERB'), ('through', 'ADP'), ('sunlight', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['was']
# was -0.40447030799388567
#
#
# hills
# [('of', 'ADP'), ('hills', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('kind', 'NOUN'), ('of', 'ADP'), ('waiting', 'VERB'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -1.3124114049161926
#
#
# world
# [('if', 'ADP'), ('the', 'DET'), ('world', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('dream', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.254877964810284
#
#
# connecticut
# [('and', 'CONJ'), ('the', 'DET'), ('rich', 'ADJ'), ('in', 'ADP'), ('connecticut', 'NOUN'), ('are', 'VERB'), ('dreamers', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['are', 'rich']
#
#
# mouth
# [('swelling', 'VERB'), ('lukewarm', 'ADJ'), ('', 'NOUN'), ('her', 'PRON'), ('mouth', 'NOUN'), ('is', 'VERB'), ('water', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.9041655298155535
#
#
# mind
# [('how', 'ADV'), ('can', 'VERB'), ('i', 'VERB'), ('tell', 'NOUN'), ('you', 'PRON'), ('my', 'PRON'), ('mind', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('blanket', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.24302877237014908
#
#
# impermanence
# [('what', 'PRON'), ('i', 'VERB'), ('like', 'VERB'), ('about', 'ADP'), ('impermanence', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('clash', 'NOUN')]
# collocates around head in sentence: ['is', 'like']
#
#
# meditation
# [('that', 'DET'), ('nighttime', 'ADJ'), ('', 'ADJ'), ('meditation', 'NOUN'), ('are', 'VERB'), ('a', 'DET'), ('mirage', 'NOUN')]
# collocates around head in sentence: ['', 'are', 'nighttime']
#
#
# earth
# [('', 'NOUN'), ('yet', 'ADV'), ('the', 'DET'), ('earth', 'NOUN'), ('is', 'VERB'), ('divinity', 'ADJ'), ('', 'ADP'), ('the', 'DET'), ('sky', 'NOUN'), ('is', 'VERB'), ('divinity', 'NOUN')]
# collocates around head in sentence: ['is', 'yet', 'divinity']
# is 0.027962357291987656
# yet -1.0036290846315559
#
#
# sky
# [('', 'NOUN'), ('yet', 'ADV'), ('the', 'DET'), ('earth', 'NOUN'), ('is', 'VERB'), ('divinity', 'ADJ'), ('', 'ADP'), ('the', 'DET'), ('sky', 'NOUN'), ('is', 'VERB'), ('divinity', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.11425969824394078
#
#
# spirits
# [('which', 'DET'), ('constant', 'ADJ'), ('spirits', 'NOUN'), ('are', 'VERB'), ('the', 'DET'), ('keepers', 'NOUN'), ('of', 'ADP'), ('', 'NOUN')]
# collocates around head in sentence: ['constant', 'are']
# are 0.4802457673051751
#
#
# mine
# [('mine', 'NOUN'), ('was', 'VERB'), ('the', 'DET'), ('scene', 'NOUN')]
# collocates around head in sentence: ['was']
# was 0.9435129172184364
#
#
# dawn
# [('but', 'CONJ'), ('the', 'DET'), ('breeze', 'NOUN'), ('of', 'ADP'), ('dawn', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('angel', 'NOUN'), ('of', 'ADP'), ('death', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -1.5320332279125932
#
#
# home
# [('you', 'PRON'), ('ca', 'VERB'), ('nt', 'VERB'), ('get', 'VERB'), ('lost', 'VERB'), ('', 'NOUN'), ('home', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('place', 'NOUN'), ('they', 'PRON'), ('cross', 'VERB'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'lost']
# is -0.32816770395274736
# lost -0.02206500612062201
#
#
# sausage
# [('and', 'CONJ'), ('he', 'PRON'), ('was', 'VERB'), ('a', 'DET'), ('maker', 'NOUN'), ('', 'VERB'), ('his', 'PRON'), ('sausage', 'NOUN'), ('was', 'VERB'), ('echt', 'ADJ')]
# collocates around head in sentence: ['was', '', 'echt']
#
#
# selves
# [('i', 'NOUN'), ('learned', 'VERB'), ('what', 'PRON'), ('the', 'DET'), ('selves', 'NOUN'), ('are', 'VERB'), ('a', 'DET'), ('man', 'NOUN'), ('can', 'VERB'), ('disown', 'VERB')]
# collocates around head in sentence: ['are']
# are 0.34374376740031315
#
#
# shopping
# [('see', 'VERB'), ('shopping', 'NOUN'), ('is', 'VERB'), ('an', 'DET'), ('art', 'ADJ'), ('form', 'NOUN')]
# collocates around head in sentence: ['see', 'is']
# see -0.6086344093944468
# is -0.6271649448177572
#
#
# callers
# [('my', 'PRON'), ('only', 'ADV'), ('other', 'ADJ'), ('callers', 'NOUN'), ('were', 'VERB'), ('the', 'DET'), ('fbi', 'NOUN')]
# collocates around head in sentence: ['other', 'were', 'only']
# other 2.515203274428206
# only 3.3992224050758773
#
#
# mind
# [('if', 'ADP'), ('you', 'PRON'), ('are', 'VERB'), ('with', 'ADP'), ('them', 'PRON'), ('', 'VERB'), ('if', 'ADP'), ('even', 'ADV'), ('mind', 'NOUN'), ('is', 'VERB'), ('friend', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['even', 'is', 'friend']
# even -0.042175029540899134
# is -0.24302877237014908
#
#
# body
# [('of', 'ADP'), ('my', 'PRON'), ('window', 'NOUN'), ('and', 'CONJ'), ('survive', 'ADJ'), ('', 'NOUN'), ('the', 'DET'), ('body', 'NOUN'), ('is', 'VERB'), ('no', 'DET'), ('illusion', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.45808207211068164
#
#
# people
# [('this', 'DET'), ('crushing', 'NOUN'), ('of', 'ADP'), ('people', 'NOUN'), ('is', 'VERB'), ('something', 'NOUN'), ('we', 'PRON'), ('live', 'VERB'), ('with', 'ADP'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -1.74058901978928
#
#
# ocean
# [('the', 'DET'), ('ocean', 'NOUN'), ('was', 'VERB'), ('salt', 'VERB'), ('before', 'ADP'), ('we', 'PRON'), ('crawled', 'VERB'), ('to', 'PRT'), ('tears', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['was', 'salt']
# was -0.9421920285947141
#
#
# street
# [('each', 'DET'), ('face', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('street', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('slice', 'NOUN'), ('of', 'ADP'), ('bread', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.6341090691269347
#
#
# chest
# [('my', 'PRON'), ('chest', 'NOUN'), ('was', 'VERB'), ('all', 'DET'), ('thunder', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['was']
# was -0.12961562041436556
#
#
# dreams
# [('through', 'ADP'), ('ivory', 'ADJ'), ('our', 'PRON'), ('dreams', 'NOUN'), ('are', 'VERB'), ('willothewisps', 'ADJ'), ('', 'NOUN'), ('scant', 'NOUN')]
# collocates around head in sentence: ['are', 'ivory', 'willothewisps']
# are 1.6968535175359551
#
#
# soldiers
# [('soldiers', 'NOUN'), ('are', 'VERB'), ('citizens', 'NOUN'), ('of', 'ADP'), ('death', 'NOUN'), ('s', 'NOUN'), ('grey', 'NOUN'), ('land', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['are']
# are 0.5287756612328338
#
#
# soldiers
# [('soldiers', 'NOUN'), ('are', 'VERB'), ('dreamers', 'NOUN'), ('', 'ADV'), ('when', 'ADV'), ('the', 'DET'), ('guns', 'NOUN'), ('begin', 'VERB')]
# collocates around head in sentence: ['are']
# are 0.5287756612328338
#
#
# wind
# [('the', 'DET'), ('wind', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('torrent', 'NOUN'), ('of', 'ADP'), ('darkness', 'NOUN'), ('among', 'ADP'), ('the', 'DET'), ('gusty', 'NOUN'), ('trees', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['was']
# was 0.2674698340417363
#
#
# road
# [('the', 'DET'), ('road', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('ribbon', 'NOUN'), ('of', 'ADP'), ('moonlight', 'NOUN'), ('over', 'ADP'), ('the', 'DET'), ('purple', 'ADJ'), ('moor', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['was']
# was -0.793705673792291
#
#
# eyes
# [('his', 'PRON'), ('eyes', 'NOUN'), ('were', 'VERB'), ('hollows', 'NOUN'), ('of', 'ADP'), ('madness', 'NOUN'), ('', 'ADP'), ('his', 'PRON'), ('hair', 'NOUN'), ('like', 'ADP'), ('mouldy', 'NOUN'), ('hay', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['were']
# were 2.108178244022888
#
#
# road
# [('when', 'ADV'), ('the', 'DET'), ('road', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('gypsy', 'NOUN'), ('s', 'NOUN'), ('ribbon', 'NOUN'), ('', 'NOUN'), ('looping', 'VERB'), ('the', 'DET'), ('purple', 'ADJ'), ('moor', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['was', 'when']
# was -0.793705673792291
# when -3.9273122990651763
#
#
# road
# [('when', 'ADV'), ('the', 'DET'), ('road', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('ribbon', 'NOUN'), ('of', 'ADP'), ('moonlight', 'NOUN'), ('over', 'ADP'), ('the', 'DET'), ('purple', 'ADJ'), ('moor', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'when']
# is -0.7614615276071368
# when -3.9273122990651763
#
#
# slopes
# [('the', 'DET'), ('watchman', 'NOUN'), ('s', 'VERB'), ('upper', 'ADJ'), ('slopes', 'NOUN'), ('were', 'VERB'), ('shadows', 'NOUN'), ('', 'VERB'), ('green', 'ADJ')]
# collocates around head in sentence: ['upper', 'were', 's']
# upper 7.993831367803994
# were -1.3387201097865777
#
#
# mind
# [('', 'VERB'), ('your', 'PRON'), ('mind', 'NOUN'), ('is', 'VERB'), ('water', 'NOUN'), ('through', 'ADP'), ('an', 'DET'), ('april', 'ADJ'), ('night', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is', '']
# is -0.24302877237014908
#
#
# laughter
# [('whose', 'PRON'), ('hideous', 'ADJ'), ('laughter', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('bellows', 'ADJ'), ('mirth', 'NOUN')]
# collocates around head in sentence: ['hideous', 'is']
# is -0.7698353810946488
#
#
# god
# [('as', 'ADP'), ('though', 'ADP'), ('a', 'DET'), ('god', 'NOUN'), ('were', 'VERB'), ('issue', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('strings', 'NOUN'), ('', 'NOUN'), ('', 'NOUN'), ('', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['were']
# were -1.7740361321238665
#
#
# unshadow
# [('whose', 'PRON'), ('fell', 'VERB'), ('unshadow', 'ADJ'), ('is', 'VERB'), ('death', 'NOUN'), ('s', 'NOUN'), ('utter', 'NOUN'), ('wound', 'NOUN'), ('', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['fell', 'is']
#
#
# road
# [('we', 'PRON'), ('are', 'VERB'), ('driving', 'VERB'), ('slowly', 'ADV'), ('', 'ADP'), ('the', 'DET'), ('road', 'NOUN'), ('is', 'VERB'), ('glass', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'glass']
# is -0.7614615276071368
#
#
# memory
# [('even', 'ADV'), ('memory', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('stranger', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['even', 'is']
# even 0.8527894997608118
# is 0.2893656775468532
#
#
# cathleen
# [('the', 'DET'), ('countess', 'NOUN'), ('cathleen', 'NOUN'), ('was', 'VERB'), ('the', 'DET'), ('name', 'NOUN'), ('i', 'NOUN'), ('gave', 'VERB'), ('it', 'PRON'), ('', 'VERB')]
# collocates around head in sentence: ['was']
#
#
# laugh
# [('the', 'DET'), ('laugh', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('cry', 'NOUN'), ('from', 'ADP'), ('my', 'PRON'), ('own', 'ADJ')]
# collocates around head in sentence: ['was']
# was -0.1728997181431656
#
#
# field
# [('in', 'ADP'), ('the', 'DET'), ('field', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('house', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.08840477176769322
#
#
# hope
# [('hope', 'NOUN'), ('is', 'VERB'), ('command', 'ADJ'), ('', 'ADP'), ('your', 'PRON'), ('hand', 'NOUN')]
# collocates around head in sentence: ['is', 'command']
# is 0.3430065187579535
#
#
# country
# [('their', 'PRON'), ('country', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('nation', 'NOUN'), ('on', 'ADP'), ('no', 'DET'), ('map', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.008617365706759013
#
#
# blacktime
# [('blacktime', 'NOUN'), ('is', 'VERB'), ('time', 'NOUN'), ('for', 'ADP'), ('chimeful', 'NOUN')]
# collocates around head in sentence: ['is']
#
#
# stuff
# [('shaving', 'VERB'), ('lotion', 'NOUN'), ('', 'NOUN'), ('as', 'ADP'), ('if', 'ADP'), ('the', 'DET'), ('stuff', 'NOUN'), ('were', 'VERB'), ('scotch', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['were', 'scotch']
# were -1.9859978163582164
#
#
# reverie
# [('our', 'PRON'), ('effort', 'NOUN'), ('to', 'PRT'), ('remake', 'VERB'), ('the', 'DET'), ('found', 'ADJ'), ('world', 'NOUN'), ('as', 'ADP'), ('the', 'DET'), ('lost', 'ADJ'), ('reverie', 'NOUN'), ('is', 'VERB'), ('desire', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['lost', 'is', 'desire']
#
#
# literature
# [('his', 'PRON'), ('literature', 'NOUN'), ('is', 'VERB'), ('lives', 'ADJ'), ('', 'NOUN'), ('is', 'VERB'), ('deif', 'ADJ'), ('smiling', 'VERB'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'lives']
# is 0.14286768528481375
#
#
# fiat
# [('he', 'PRON'), ('speaks', 'VERB'), ('', 'VERB'), ('his', 'PRON'), ('fiat', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('fiat', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is', '']
# is 0.5204786092485489
#
#
# father
# [('whitman', 'NOUN'), ('s', 'VERB'), ('father', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('carpenter', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['s', 'was']
# was 1.273435205902272
#
#
# workmen
# [('that', 'ADP'), ('all', 'DET'), ('workmen', 'NOUN'), ('are', 'VERB'), ('singers', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['are']
# are -0.24121873332084323
#
#
# weight
# [('to', 'PRT'), ('other', 'ADJ'), ('laws', 'NOUN'), ('', 'ADJ'), ('weight', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('measure', 'NOUN'), ('of', 'ADP')]
# collocates around head in sentence: ['', 'is']
# is 0.12539336763356293
#
#
# unclean
# [('unclean', 'ADJ'), ('is', 'VERB'), ('the', 'DET'), ('nature', 'NOUN'), ('and', 'CONJ'), ('name', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('enchantment', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is 1.0655766490917657
#
#
# bed
# [('going', 'VERB'), ('to', 'PRT'), ('bed', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('journey', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['was', 'going']
# was -0.6363674375892283
# going 3.2502766834014696
#
#
# masks
# [('the', 'DET'), ('fateful', 'ADJ'), ('masks', 'NOUN'), ('are', 'VERB'), ('faces', 'VERB'), ('', 'ADJ'), ('gods', 'NOUN'), ('are', 'VERB'), ('men', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['fateful', 'are', 'faces']
#
#
# gods
# [('the', 'DET'), ('fateful', 'ADJ'), ('masks', 'NOUN'), ('are', 'VERB'), ('faces', 'VERB'), ('', 'ADJ'), ('gods', 'NOUN'), ('are', 'VERB'), ('men', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['', 'are', 'faces']
# are 2.1260430413885874
#
#
# telephone
# [('the', 'DET'), ('telephone', 'NOUN'), ('is', 'VERB'), ('flaubert', 'ADJ'), ('s', 'ADJ'), ('parrot', 'NOUN'), ('and', 'CONJ'), ('it', 'PRON'), ('flitters', 'NOUN')]
# collocates around head in sentence: ['is', 'flaubert']
# is -0.9529288197603077
#
#
# telephone
# [('of', 'ADP'), ('her', 'PRON'), ('', 'NOUN'), ('the', 'DET'), ('telephone', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('guignol', 'NOUN'), ('of', 'ADP')]
# collocates around head in sentence: ['is']
# is -0.9529288197603077
#
#
# men
# [('city', 'NOUN'), ('of', 'ADP'), ('rock', 'NOUN'), ('and', 'CONJ'), ('ice', 'NOUN'), ('', 'NOUN'), ('that', 'ADP'), ('men', 'NOUN'), ('are', 'VERB'), ('freaks', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['are']
# are 1.2652417937215954
#
#
# it
# [('it', 'PRON'), ('is', 'VERB'), ('not', 'ADV'), ('you', 'PRON'), ('i', 'VERB'), ('love', 'VERB'), ('it', 'PRON'), ('is', 'VERB'), ('the', 'DET'), ('form', 'NOUN')]
# collocates around head in sentence: ['love', 'is', 'i']
# love -0.8192619172019077
# is 2.364290732064418
# i -7.156050550641081
#
#
# death
# [('the', 'DET'), ('thought', 'NOUN'), ('of', 'ADP'), ('death', 'NOUN'), ('is', 'VERB'), ('peppermint', 'ADJ'), ('to', 'PRT'), ('you', 'PRON')]
# collocates around head in sentence: ['is', 'peppermint']
# is 0.03210803554954114
#
#
# fresher
# [('scarce', 'NOUN'), ('fresher', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('mountainsod', 'NOUN')]
# collocates around head in sentence: ['is']
#
#
# heart
# [('but', 'CONJ'), ('', 'NOUN'), ('ah', 'VERB'), ('', 'VERB'), ('its', 'PRON'), ('heart', 'NOUN'), ('', 'VERB'), ('its', 'PRON'), ('heart', 'NOUN'), ('was', 'VERB'), ('stone', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['was', '', 'stone']
# was -0.23275961818465274
#
#
# soul
# [('but', 'CONJ'), ('for', 'ADP'), ('peace', 'NOUN'), ('her', 'PRON'), ('soul', 'NOUN'), ('was', 'VERB'), ('yearning', 'VERB'), ('', 'NOUN')]
# collocates around head in sentence: ['was', 'yearning']
# was -0.42502363827669526
# yearning 6.343105856401491
#
#
# heart
# [('o', 'ADJ'), ('sohrab', 'NOUN'), ('', 'VERB'), ('an', 'DET'), ('unquiet', 'ADJ'), ('heart', 'NOUN'), ('is', 'VERB'), ('thine', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['unquiet', 'is', 'thine']
# is -0.2763468849591445
#
#
# culture
# [('whose', 'PRON'), ('culture', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('brethren', 'NOUN'), ('s', 'VERB'), ('care', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.6695583074868326
#
#
# brooks
# [('and', 'CONJ'), ('what', 'PRON'), ('sedged', 'VERB'), ('brooks', 'NOUN'), ('are', 'VERB'), ('thames', 'ADV'), ('s', 'ADJ'), ('tributaries', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['sedged', 'are', 'thames']
#
#
# rights
# [('thy', 'ADJ'), ('rights', 'NOUN'), ('are', 'VERB'), ('empire', 'ADJ'), ('', 'NOUN'), ('urge', 'NOUN'), ('no', 'DET'), ('meaner', 'NOUN'), ('claim', 'NOUN'), ('', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['thy', 'are', 'empire']
# are 0.4648104013395741
#
#
# i
# [('answer', 'NOUN'), ('d', 'VERB'), ('the', 'DET'), ('lovely', 'ADJ'), ('maid', 'NOUN'), ('and', 'CONJ'), ('said', 'VERB'), ('', 'NOUN'), ('i', 'NOUN'), ('am', 'VERB'), ('a', 'DET'), ('watry', 'NOUN'), ('weed', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['am', 'said']
# am 5.424708596281558
# said 1.4201618916086762
#
#
# ways
# [('and', 'CONJ'), ('their', 'PRON'), ('ways', 'NOUN'), ('are', 'VERB'), ('fill', 'ADJ'), ('d', 'NOUN'), ('with', 'ADP'), ('thorns', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['are', 'fill']
# are 1.6492615045556203
#
#
# breast
# [('his', 'PRON'), ('breast', 'NOUN'), ('is', 'VERB'), ('love', 'ADJ'), ('s', 'ADV'), ('all', 'DET'), ('worship', 'NOUN'), ('d', 'VERB'), ('tomb', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'love']
# is 0.269935147597952
#
#
# peace
# [('', 'ADJ'), ('no', 'DET'), ('peace', 'NOUN'), ('be', 'VERB'), ('thine', 'ADJ'), ('', 'NOUN'), ('', 'NOUN'), ('exclaimed', 'VERB'), ('', 'NOUN'), ('away', 'ADV'), ('', 'VERB'), ('away', 'ADV'), ('', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['be', '', 'thine']
# be -0.4050747482281715
#
#
# arts
# [('inventing', 'VERB'), ('one', 'NUM'), ('', 'NOUN'), ('in', 'ADP'), ('brief', 'ADJ'), ('', 'NOUN'), ('all', 'DET'), ('arts', 'NOUN'), ('are', 'VERB'), ('mine', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['are', 'mine']
# are -0.27912152545843855
#
#
# outside
# [('outside', 'NOUN'), ('was', 'VERB'), ('all', 'DET'), ('noon', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('burning', 'VERB'), ('blue', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['was']
# was -0.1378405071918006
#
#
# i
# [('i', 'NOUN'), ('am', 'VERB'), ('the', 'DET'), ('resurrection', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('life', 'NOUN'), ('', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['am']
# am 5.424708596281558
#
#
# earth
# [('take', 'VERB'), ('away', 'PRT'), ('love', 'VERB'), ('', 'NOUN'), ('and', 'CONJ'), ('our', 'PRON'), ('earth', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('tomb', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.027962357291987656
#
#
# friars
# [('first', 'ADV'), ('', 'ADJ'), ('every', 'DET'), ('sort', 'NOUN'), ('of', 'ADP'), ('monk', 'NOUN'), ('', 'VERB'), ('the', 'DET'), ('black', 'ADJ'), ('and', 'CONJ'), ('whitethe', 'ADJ'), ('black', 'ADJ'), ('and', 'CONJ'), ('the', 'DET'), ('white', 'ADJ'), ('black', 'ADJ'), ('friars', 'NOUN'), ('are', 'VERB'), ('dominicans', 'NOUN'), ('', 'ADJ'), ('white', 'ADJ'), ('friars', 'NOUN'), ('are', 'VERB'), ('carmelites', 'NOUN'), ('', 'ADP')]
# collocates around head in sentence: ['black', 'are', 'white']
# black 7.261929697085368
#
#
# friars
# [('first', 'ADV'), ('', 'ADJ'), ('every', 'DET'), ('sort', 'NOUN'), ('of', 'ADP'), ('monk', 'NOUN'), ('', 'VERB'), ('the', 'DET'), ('black', 'ADJ'), ('and', 'CONJ'), ('whitethe', 'ADJ'), ('black', 'ADJ'), ('and', 'CONJ'), ('the', 'DET'), ('white', 'ADJ'), ('black', 'ADJ'), ('friars', 'NOUN'), ('are', 'VERB'), ('dominicans', 'NOUN'), ('', 'ADJ'), ('white', 'ADJ'), ('friars', 'NOUN'), ('are', 'VERB'), ('carmelites', 'NOUN'), ('', 'ADP')]
# collocates around head in sentence: ['white', 'are', '']
#
#
# name
# [('his', 'PRON'), ('name', 'NOUN'), ('is', 'VERB'), ('guidi', 'ADJ'), ('', 'ADP'), ('he', 'PRON'), ('ll', 'VERB'), ('not', 'ADV'), ('mind', 'VERB'), ('the', 'DET'), ('monks', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['is', 'guidi']
# is 0.7423927627069589
#
#
# sparkle
# [('no', 'DET'), ('yonder', 'NOUN'), ('sparkle', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('citadel', 'NOUN'), ('s', 'NOUN')]
# collocates around head in sentence: ['is']
#
#
# life
# [('our', 'PRON'), ('low', 'ADJ'), ('life', 'NOUN'), ('was', 'VERB'), ('the', 'DET'), ('level', 'NOUN'), ('s', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('night', 'NOUN'), ('s', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['low', 'was']
# low -0.22349412571889402
# was -0.07636651185532756
#
#
# star
# [('what', 'PRON'), ('matter', 'NOUN'), ('to', 'PRT'), ('me', 'PRON'), ('if', 'ADP'), ('their', 'PRON'), ('star', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('world', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.02704659015917948
#
#
# god
# [('and', 'CONJ'), ('with', 'ADP'), ('god', 'NOUN'), ('be', 'VERB'), ('the', 'DET'), ('rest', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['be']
# be -0.5798288504111871
#
#
# merchants
# [('what', 'PRON'), ('', 'VERB'), ('they', 'PRON'), ('lived', 'VERB'), ('once', 'ADV'), ('thus', 'ADV'), ('at', 'ADP'), ('venice', 'NOUN'), ('where', 'ADV'), ('the', 'DET'), ('merchants', 'NOUN'), ('were', 'VERB'), ('the', 'DET'), ('kings', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['were', 'where']
# were 1.8511044490934394
#
#
# fate
# [('that', 'DET'), ('fate', 'NOUN'), ('is', 'VERB'), ('thine', 'ADJ'), ('', 'NOUN'), ('no', 'DET'), ('distant', 'ADJ'), ('date', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'thine']
# is 0.1834436219709782
#
#
# they
# [('hissing', 'VERB'), ('', 'NOUN'), ('but', 'CONJ'), ('stingless', 'NOUN'), ('they', 'PRON'), ('were', 'VERB'), ('slain', 'VERB'), ('for', 'ADP'), ('food', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['were', 'slain']
# were 3.291163137435543
#
#
# road
# [('what', 'PRON'), ('matters', 'VERB'), ('if', 'ADP'), ('the', 'DET'), ('road', 'NOUN'), ('be', 'VERB'), ('head', 'VERB'), ('or', 'CONJ'), ('heart', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['be', 'head']
# be -2.977795736194389
#
#
# juan
# [('but', 'CONJ'), ('juan', 'NOUN'), ('was', 'VERB'), ('receiv', 'ADJ'), ('d', 'NOUN'), ('with', 'ADP'), ('much', 'ADJ'), ('empressement', 'NOUN'), ('', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['was', 'receiv']
# was -1.0232636392420318
#
#
# life
# [('my', 'PRON'), ('whole', 'ADJ'), ('life', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('contest', 'NOUN'), ('', 'NOUN'), ('since', 'ADP'), ('the', 'DET'), ('day', 'NOUN')]
# collocates around head in sentence: ['whole', 'was']
# whole 2.284236752848861
# was -0.07636651185532756
#
#
# limbs
# [('my', 'PRON'), ('limbs', 'NOUN'), ('are', 'VERB'), ('bow', 'ADJ'), ('d', 'ADJ'), ('', 'NOUN'), ('though', 'ADP'), ('not', 'ADV'), ('with', 'ADP'), ('toil', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['are', 'bow']
# are 0.3238442099626081
#
#
# dungeon
# [('to', 'PRT'), ('him', 'PRON'), ('this', 'DET'), ('dungeon', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('gulf', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['was']
#
#
# man
# [('the', 'DET'), ('thriftiest', 'NOUN'), ('man', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('cheerfulest', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.17024889347957267
#
#
# earth
# [('what', 'PRON'), ('on', 'ADP'), ('earth', 'NOUN'), ('was', 'VERB'), ('the', 'DET'), ('helmsman', 'NOUN'), ('to', 'PRT'), ('do', 'VERB'), ('', 'VERB')]
# collocates around head in sentence: ['was']
# was 0.11279260629836087
#
#
# snark
# [('', 'NOUN'), ('if', 'ADP'), ('your', 'PRON'), ('snark', 'NOUN'), ('be', 'VERB'), ('a', 'DET'), ('snark', 'NOUN'), ('', 'NOUN'), ('that', 'DET'), ('is', 'VERB'), ('right', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['be']
#
#
# folk
# [('among', 'ADP'), ('thise', 'NOUN'), ('othere', 'ADV'), ('folk', 'NOUN'), ('was', 'VERB'), ('criseyda', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['othere', 'was', 'criseyda']
# was -0.8048076324647542
#
#
# opyn
# [('of', 'ADP'), ('dardanus', 'NOUN'), ('', 'NOUN'), ('ther', 'NOUN'), ('opyn', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('cheyne', 'NOUN'), ('', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
#
#
# gold
# [('burning', 'VERB'), ('hot', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('ground', 'NOUN'), ('', 'NOUN'), ('liquid', 'NOUN'), ('gold', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('air', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.8539613227999556
#
#
# hopes
# [('if', 'ADP'), ('hopes', 'NOUN'), ('were', 'VERB'), ('dupes', 'NOUN'), ('', 'ADJ'), ('fears', 'NOUN'), ('may', 'VERB'), ('be', 'VERB'), ('liars', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['were']
# were 1.4538173519520141
#
#
# night
# [('the', 'DET'), ('night', 'NOUN'), ('is', 'VERB'), ('chill', 'ADJ'), ('', 'ADP'), ('the', 'DET'), ('cloud', 'NOUN'), ('is', 'VERB'), ('gray', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'chill']
# is -1.8835393330637662
# chill 2.7384238235582816
#
#
# night
# [('the', 'DET'), ('night', 'NOUN'), ('is', 'VERB'), ('chill', 'ADJ'), ('', 'ADP'), ('the', 'DET'), ('forest', 'ADJ'), ('bare', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'chill']
# is -1.8835393330637662
# chill 2.7384238235582816
#
#
# name
# [('and', 'CONJ'), ('my', 'PRON'), ('name', 'NOUN'), ('is', 'VERB'), ('geraldine', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'geraldine']
# is 0.7423927627069589
#
#
# bones
# [('the', 'DET'), ('knight', 'NOUN'), ('s', 'NOUN'), ('bones', 'NOUN'), ('are', 'VERB'), ('dust', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['are', 'dust']
# are 1.0261941130235248
#
#
# wave
# [('the', 'DET'), ('western', 'ADJ'), ('wave', 'NOUN'), ('was', 'VERB'), ('all', 'DET'), ('aflame', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['western', 'was']
# was -0.24780452715705656
#
#
# friendship
# [('friendship', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('sheltering', 'VERB'), ('tree', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.37096506782919664
#
#
# lips
# [('those', 'DET'), ('lips', 'NOUN'), ('are', 'VERB'), ('thine', 'ADJ'), ('', 'NOUN'), ('thy', 'NOUN'), ('own', 'ADJ'), ('sweet', 'ADJ'), ('smiles', 'NOUN'), ('i', 'VERB'), ('see', 'VERB'), ('', 'ADJ')]
# collocates around head in sentence: ['are', 'thine']
# are -0.12191980494849872
#
#
# eyes
# [('', 'VERB'), ('a', 'DET'), ('sight', 'NOUN'), ('to', 'PRT'), ('which', 'DET'), ('our', 'PRON'), ('eyes', 'NOUN'), ('are', 'VERB'), ('strangers', 'NOUN'), ('yet', 'ADV'), ('', 'VERB')]
# collocates around head in sentence: ['are']
# are 0.47612181488044686
#
#
# youth
# [('to', 'PRT'), ('me', 'PRON'), ('the', 'DET'), ('children', 'NOUN'), ('of', 'ADP'), ('my', 'PRON'), ('youth', 'NOUN'), ('are', 'VERB'), ('lords', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['are']
# are -0.6933455513349073
#
#
# mercy
# [('and', 'CONJ'), ('whose', 'PRON'), ('most', 'ADV'), ('tender', 'NOUN'), ('mercy', 'NOUN'), ('is', 'VERB'), ('neglect', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'most', 'neglect']
# is 0.616304101748613
#
#
# smiles
# [('her', 'PRON'), ('smiles', 'NOUN'), ('are', 'VERB'), ('lightning', 'VERB'), ('though', 'ADP'), ('her', 'PRON'), ('pride', 'NOUN'), ('despair', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['are', 'lightning']
# are -0.41114373476315563
#
#
# love
# [('you', 'PRON'), ('', 'VERB'), ('to', 'PRT'), ('whom', 'PRON'), ('love', 'NOUN'), ('was', 'VERB'), ('peace', 'NOUN'), ('', 'NOUN'), ('that', 'DET'), ('now', 'ADV'), ('is', 'VERB'), ('rage', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['was']
# was -0.1657752837097842
#
#
# soul
# [('', 'NOUN'), ('whose', 'PRON'), ('soul', 'NOUN'), ('is', 'VERB'), ('sense', 'ADJ'), ('', 'NOUN'), ('cannot', 'NOUN'), ('admit', 'NOUN')]
# collocates around head in sentence: ['is', 'sense']
# is 0.1284244279705442
#
#
# life
# [('can', 'VERB'), ('life', 'NOUN'), ('be', 'VERB'), ('a', 'DET'), ('blessing', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['can', 'be']
# can -0.21133745030667242
# be -1.0618181439002974
#
#
# life
# [('can', 'VERB'), ('life', 'NOUN'), ('be', 'VERB'), ('a', 'DET'), ('blessing', 'NOUN'), ('if', 'ADP'), ('love', 'NOUN'), ('were', 'VERB'), ('away', 'ADV'), ('', 'ADJ')]
# collocates around head in sentence: ['can', 'be']
# can -0.21133745030667242
# be -1.0618181439002974
#
#
# queens
# [('where', 'ADV'), ('queens', 'NOUN'), ('are', 'VERB'), ('form', 'ADJ'), ('d', 'NOUN'), ('', 'NOUN'), ('and', 'CONJ'), ('future', 'ADJ'), ('heroes', 'NOUN'), ('bred', 'VERB'), ('', 'NOUN')]
# collocates around head in sentence: ['where', 'are', 'form']
#
#
# herringman
# [('and', 'CONJ'), ('herringman', 'NOUN'), ('was', 'VERB'), ('captain', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('guard', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['was']
#
#
# kind
# [('kind', 'NOUN'), ('is', 'VERB'), ('death', 'NOUN'), ('that', 'ADP'), ('ends', 'VERB'), ('my', 'PRON'), ('pain', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.13865050882130528
#
#
# poetry
# [('but', 'CONJ'), ('now', 'ADV'), ('', 'VERB'), ('not', 'ADV'), ('i', 'ADJ'), ('', 'VERB'), ('but', 'CONJ'), ('poetry', 'VERB'), ('is', 'VERB'), ('curs', 'ADJ'), ('d', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is', '', 'curs']
# is 0.37955963877245
#
#
# slight
# [('slight', 'NOUN'), ('was', 'VERB'), ('the', 'DET'), ('thing', 'NOUN'), ('i', 'NOUN'), ('bought', 'VERB'), ('', 'NOUN')]
# collocates around head in sentence: ['was']
# was 0.9109458902276595
#
#
# client
# [('said', 'VERB'), ('his', 'PRON'), ('client', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('martyr', 'NOUN')]
# collocates around head in sentence: ['was', 'said']
# was -0.8435920928902058
# said 0.9758808172316679
#
#
# side
# [('what', 'PRON'), ('held', 'VERB'), ('it', 'PRON'), ('though', 'ADP'), ('on', 'ADP'), ('one', 'NUM'), ('side', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('tree', 'NOUN')]
# collocates around head in sentence: ['was']
# was -1.1493575242758216
#
#
# ignorance
# [('no', 'DET'), ('more', 'ADV'), ('', 'ADJ'), ('where', 'ADV'), ('ignorance', 'NOUN'), ('is', 'VERB'), ('bliss', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['where', 'is', '', 'bliss']
# where 0.6061300653674381
# is 0.584043738026015
#
#
# soul
# [('until', 'ADP'), ('somehow', 'ADV'), ('yer', 'ADJ'), ('soul', 'NOUN'), ('is', 'VERB'), ('sort', 'ADJ'), ('o', 'ADJ'), ('', 'NOUN'), ('wrapped', 'VERB'), ('round', 'NOUN'), ('everything', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['yer', 'is', 'somehow', 'sort']
# is 0.1284244279705442
# somehow 3.106990575264712
#
#
# death
# [('an', 'DET'), ('watch', 'NOUN'), ('beside', 'ADP'), ('a', 'DET'), ('loved', 'ADJ'), ('one', 'NUM'), ('s', 'NOUN'), ('bed', 'VERB'), ('', 'NOUN'), ('an', 'DET'), ('know', 'VERB'), ('that', 'ADP'), ('death', 'NOUN'), ('is', 'VERB'), ('nigh', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'know', 'nigh']
# is 0.03210803554954114
# know -2.924393208087906
#
#
# stuff
# [('my', 'PRON'), ('stuff', 'NOUN'), ('is', 'VERB'), ('flesh', 'ADJ'), ('', 'NOUN'), ('not', 'ADV'), ('brass', 'ADV'), ('', 'VERB'), ('my', 'PRON'), ('senses', 'NOUN'), ('live', 'VERB'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'flesh']
# is 0.9260211891597898
#
#
# jewels
# [('jewels', 'NOUN'), ('are', 'VERB'), ('baubles', 'NOUN'), ('', 'NOUN'), ('t', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('sin', 'NOUN')]
# collocates around head in sentence: ['are']
# are 1.4262059275922858
#
#
# beauty
# [('a', 'DET'), ('thing', 'NOUN'), ('of', 'ADP'), ('beauty', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('joy', 'NOUN'), ('for', 'ADP'), ('ever', 'ADV'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.014156557766957135
#
#
# bearing
# [('and', 'CONJ'), ('in', 'ADP'), ('her', 'PRON'), ('bearing', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('sort', 'NOUN'), ('of', 'ADP'), ('hope', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['was']
# was -1.403593403934741
#
#
# beauty
# [('beauty', 'NOUN'), ('is', 'VERB'), ('truth', 'ADJ'), ('', 'ADJ'), ('truth', 'NOUN'), ('beauty', 'NOUN'), ('', 'NOUN'), ('', 'NOUN'), ('that', 'DET'), ('is', 'VERB'), ('all', 'DET')]
# collocates around head in sentence: ['is', 'truth']
# is 0.014156557766957135
#
#
# veil
# [('so', 'ADV'), ('thou', 'ADJ'), ('wast', 'NOUN'), ('blind', 'ADP'), ('', 'ADJ'), ('', 'NOUN'), ('but', 'CONJ'), ('then', 'ADV'), ('the', 'DET'), ('veil', 'NOUN'), ('was', 'VERB'), ('rent', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['was', 'then', 'rent']
#
#
# death
# [('the', 'DET'), ('mourners', 'NOUN'), ('said', 'VERB'), ('', 'ADJ'), ('', 'NOUN'), ('and', 'CONJ'), ('death', 'NOUN'), ('is', 'VERB'), ('rest', 'ADJ'), ('and', 'CONJ'), ('peace', 'NOUN'), ('', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'rest']
# is 0.03210803554954114
#
#
# image
# [('the', 'DET'), ('image', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('adversary', 'ADJ'), ('old', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.48465248562151386
#
#
# aim
# [('whose', 'PRON'), ('aim', 'NOUN'), ('is', 'VERB'), ('vanity', 'ADJ'), ('', 'NOUN'), ('and', 'CONJ'), ('whose', 'PRON'), ('end', 'NOUN'), ('is', 'VERB'), ('pain', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'vanity']
# is 2.359572360082628
#
#
# end
# [('whose', 'PRON'), ('aim', 'NOUN'), ('is', 'VERB'), ('vanity', 'ADJ'), ('', 'NOUN'), ('and', 'CONJ'), ('whose', 'PRON'), ('end', 'NOUN'), ('is', 'VERB'), ('pain', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'pain']
# is -1.294528887055738
#
#
# age
# [('for', 'ADP'), ('age', 'NOUN'), ('is', 'VERB'), ('opportunity', 'NOUN'), ('no', 'ADV'), ('less', 'ADV')]
# collocates around head in sentence: ['is']
# is -0.6722090606206605
#
#
# rock
# [('as', 'ADP'), ('of', 'ADP'), ('a', 'DET'), ('rock', 'NOUN'), ('was', 'VERB'), ('the', 'DET'), ('shock', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['was']
# was -1.2160729490749675
#
#
# heart
# [('relenting', 'VERB'), ('hero', 'NOUN'), ('s', 'NOUN'), ('gentle', 'ADJ'), ('heart', 'NOUN'), ('was', 'VERB'), ('strook', 'VERB'), ('', 'NOUN')]
# collocates around head in sentence: ['gentle', 'was', 'strook']
# was -0.23275961818465274
#
#
# world
# [('another', 'DET'), ('world', 'NOUN'), ('was', 'VERB'), ('search', 'ADJ'), ('d', 'NOUN'), ('', 'NOUN'), ('through', 'ADP'), ('oceans', 'NOUN'), ('new', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['was', 'search']
# was -0.6141018949813768
#
#
# things
# ...
#
# petunias
# [('sex', 'NOUN'), ('please', 'NOUN'), ('now', 'ADV'), ('', 'VERB'), ('petunias', 'NOUN'), ('are', 'VERB'), ('an', 'DET'), ('apology', 'NOUN')]
# collocates around head in sentence: ['', 'are', 'now']
# are 3.4692746494841717
#
#
# desert
# [('long', 'ADV'), ('ago', 'ADV'), ('', 'VERB'), ('this', 'DET'), ('desert', 'NOUN'), ('was', 'VERB'), ('an', 'DET'), ('inland', 'NOUN'), ('sea', 'NOUN'), ('', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('mountains', 'NOUN')]
# collocates around head in sentence: ['was', '']
# was 0.054476110707538085
#
#
# name
# [('my', 'PRON'), ('name', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('household', 'NOUN'), ('word', 'NOUN'), ('', 'NOUN'), ('writes', 'VERB'), ('the', 'DET'), ('hid', 'NOUN'), ('teacher', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.7423927627069589
#
#
# horse
# [('the', 'DET'), ('horse', 'NOUN'), ('was', 'VERB'), ('midnight', 'NOUN')]
# collocates around head in sentence: ['was']
# was -0.06567080985243948
#
#
# dey
# [('i', 'NOUN'), ('would', 'VERB'), ('have', 'VERB'), ('freed', 'VERB'), ('thousands', 'NOUN'), ('mo', 'ADV'), ('', 'ADV'), ('if', 'ADP'), ('dey', 'VERB'), ('had', 'VERB'), ('known', 'VERB'), ('dey', 'NOUN'), ('were', 'VERB'), ('slaves', 'NOUN'), ('', 'VERB'), ('harriet', 'ADJ')]
# collocates around head in sentence: ['known', 'were', 'had']
#
#
# rooms
# [('in', 'ADP'), ('a', 'DET'), ('hundred', 'NUM'), ('furnished', 'ADJ'), ('rooms', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('girl', 'NOUN'), ('who', 'PRON'), ('sells', 'VERB'), ('silk', 'NOUN'), ('or', 'CONJ'), ('dress', 'NOUN'), ('goods', 'NOUN'), ('or', 'CONJ'), ('leather', 'ADJ'), ('stuff', 'NOUN'), ('for', 'ADP')]
# collocates around head in sentence: ['furnished', 'is']
# furnished 7.743392655011177
# is -2.407576596358012
#
#
# law
# [('the', 'DET'), ('law', 'NOUN'), ('was', 'VERB'), ('move', 'NOUN'), ('or', 'CONJ'), ('die', 'NOUN'), ('', 'VERB'), ('lively', 'ADV'), ('from', 'ADP'), ('tigers', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['was']
# was -0.46249629294010575
#
#
# day
# [('our', 'PRON'), ('day', 'NOUN'), ('is', 'VERB'), ('night', 'NOUN'), ('when', 'ADV'), ('we', 'PRON'), ('sit', 'VERB'), ('in', 'ADP'), ('rows', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('classroom', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.9613903985085038
#
#
# sun
# [('the', 'DET'), ('sun', 'NOUN'), ('is', 'VERB'), ('no', 'DET'), ('enemy', 'NOUN'), ('to', 'PRT'), ('the', 'DET'), ('eye', 'NOUN'), ('looking', 'VERB'), ('west', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.24763935229275663
#
#
# artistry
# [('i', 'NOUN'), ('have', 'VERB'), ('a', 'DET'), ('sister', 'NOUN'), ('who', 'PRON'), ('takes', 'VERB'), ('care', 'NOUN'), ('of', 'ADP'), ('animals', 'NOUN'), ('', 'VERB'), ('whose', 'PRON'), ('artistry', 'NOUN'), ('is', 'VERB'), ('flesh', 'ADJ')]
# collocates around head in sentence: ['is', '', 'flesh']
#
#
# odors
# [('reddening', 'VERB'), ('the', 'DET'), ('bare', 'NOUN'), ('skin', 'NOUN'), ('around', 'ADP'), ('the', 'DET'), ('wound', 'NOUN'), ('', 'VERB'), ('the', 'DET'), ('odors', 'NOUN'), ('are', 'VERB'), ('a', 'DET'), ('mixture', 'NOUN')]
# collocates around head in sentence: ['are', '']
#
#
# elegies
# [('the', 'DET'), ('elegies', 'NOUN'), ('were', 'VERB'), ('a', 'DET'), ('medicine', 'NOUN'), ('prescribed', 'VERB'), ('by', 'ADP'), ('the', 'DET'), ('physicians', 'NOUN')]
# collocates around head in sentence: ['were']
#
#
# past
# [('the', 'DET'), ('empty', 'ADJ'), ('hallway', 'NOUN'), ('', 'ADP'), ('the', 'DET'), ('past', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('self', 'NOUN'), ('s', 'ADJ'), ('ghoul', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.7264554058335673
#
#
# back
# [('his', 'PRON'), ('back', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('saddle', 'ADJ'), ('where', 'ADV'), ('lovers', 'NOUN'), ('have', 'VERB'), ('ridden', 'VERB'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -1.4747048581210986
#
#
# h
# [('the', 'DET'), ('horizon', 'NOUN'), ('h', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('point', 'NOUN'), ('where', 'ADV'), ('vision', 'NOUN'), ('ends', 'VERB')]
# collocates around head in sentence: ['is']
# is 0.30807027648472307
#
#
# people
# [('where', 'ADV'), ('people', 'NOUN'), ('were', 'VERB'), ('days', 'NOUN'), ('becoming', 'VERB'), ('months', 'NOUN'), ('and', 'CONJ'), ('years', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['where', 'were']
# where 0.4539118610201535
# were 1.7294839669501596
#
#
# breath
# [('the', 'DET'), ('wind', 'NOUN'), ('of', 'ADP'), ('my', 'PRON'), ('breath', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('hurricane', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -1.901383089144227
#
#
# word
# [('but', 'CONJ'), ('the', 'DET'), ('word', 'NOUN'), ('is', 'VERB'), ('mindful', 'ADJ'), ('of', 'ADP'), ('itself', 'PRON')]
# collocates around head in sentence: ['is', 'mindful']
# is 0.46207309739373903
#
#
# ghost
# [('they', 'PRON'), ('say', 'VERB'), ('a', 'DET'), ('ghost', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('ghost', 'NOUN')]
# collocates around head in sentence: ['is', 'say']
# is -0.6741084464280326
#
#
# talk
# [('yes', 'ADV'), ('', 'VERB'), ('the', 'DET'), ('sun', 'NOUN'), ('at', 'ADP'), ('its', 'PRON'), ('zenith', 'NOUN'), ('', 'NOUN'), ('winged', 'VERB'), ('figure', 'NOUN'), ('with', 'ADP'), ('arms', 'NOUN'), ('extended', 'VERB'), ('', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('white', 'ADJ'), ('ship', 'NOUN'), ('', 'NOUN'), ('exactly', 'ADV'), ('correct', 'VERB'), ('', 'ADJ'), ('let', 'VERB'), ('me', 'PRON'), ('tell', 'VERB'), ('you', 'PRON'), ('what', 'PRON'), ('it', 'PRON'), ('is', 'VERB'), ('you', 'PRON'), ('said', 'VERB'), ('', '.'), ('the', 'DET'), ('lovers', 'NOUN'), ('', 'VERB'), ('limbs', 'ADJ'), ('twist', 'NOUN'), ('like', 'ADP'), ('a', 'DET'), ('river', 'NOUN'), ('', 'PRT'), ('their', 'PRON'), ('talk', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('naming', 'NOUN'), ('or', 'CONJ'), ('being', 'VERB'), ('named', 'VERB'), ('', 'ADP'), ('my', 'PRON'), ('back', 'NOUN'), ('sometimes', 'ADV'), ('aches', 'VERB'), ('', 'VERB'), ('their', 'PRON'), ('talk', 'NOUN'), ('hides', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('telling', 'NOUN'), ('', 'VERB'), ('the', 'DET'), ('wind', 'NOUN'), ('moves', 'VERB'), ('us', 'PRON'), ('', 'ADJ'), ('wands', 'NOUN'), ('comes', 'VERB'), ('and', 'CONJ'), ('cups', 'NOUN'), ('', 'VERB'), ('gardens', 'NOUN'), ('', 'VERB'), ('someone', 'NOUN'), ('in', 'ADP'), ('a', 'DET'), ('cloak', 'NOUN'), ('', 'VERB'), ('the', 'DET'), ('wind', 'NOUN'), ('moves', 'VERB'), ('us', 'PRON'), ('', 'ADJ'), ('laws', 'NOUN'), ('', 'VERB'), ('young', 'ADJ'), ('girl', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('bird', 'NOUN'), ('at', 'ADP'), ('her', 'PRON'), ('wrist', 'NOUN'), ('', 'NOUN'), ('colors', 'NOUN'), ('', 'VERB'), ('bright', 'ADJ'), ('yellow', 'NOUN'), ('or', 'CONJ'), ('blue', 'ADJ'), ('', 'NOUN'), ('i', 'NOUN'), ('am', 'VERB'), ('a', 'DET'), ('woman', 'NOUN'), ('or', 'CONJ'), ('man', 'NOUN'), ('under', 'ADP'), ('green', 'ADJ'), ('sky', 'NOUN'), ('', 'NOUN'), ('garden', 'NOUN'), ('to', 'PRT'), ('my', 'PRON'), ('right', 'NOUN'), ('and', 'CONJ'), ('then', 'ADV'), ('it', 'PRON'), ('s', 'VERB'), ('the', 'DET'), ('following', 'ADJ'), ('day', 'NOUN'), ('', 'NOUN'), ('i', 'NOUN'), ('am', 'VERB'), ('woman', 'NOUN'), ('or', 'CONJ'), ('man', 'NOUN'), ('under', 'ADP'), ('emerald', 'ADJ'), ('sky', 'NOUN'), ('', 'NOUN'), ('wind', 'NOUN'), ('brushes', 'VERB'), ('the', 'DET'), ('river', 'NOUN'), ('s', 'VERB'), ('surface', 'ADJ'), ('', 'NOUN'), ('we', 'PRON'), ('talk', 'VERB'), ('until', 'ADP'), ('our', 'PRON'), ('talk', 'NOUN'), ('becomes', 'VERB'), ('hidden', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.2230540726088829
#
#
# talk
# [('talk', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('naming', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.2230540726088829
#
#
# talk
# [('talk', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('naming', 'NOUN'), ('or', 'CONJ'), ('a', 'DET'), ('being', 'VERB'), ('named', 'VERB'), ('', 'NOUN'), ('', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.2230540726088829
#
#
# doldrums
# [('whose', 'PRON'), ('doldrums', 'NOUN'), ('are', 'VERB'), ('meadows', 'ADJ'), ('spinning', 'VERB'), ('into', 'ADP'), ('brush', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['are', 'meadows']
# are 1.6067781732341067
#
#
# name
# [('her', 'PRON'), ('name', 'NOUN'), ('was', 'VERB'), ('sara', 'ADJ'), ('and', 'CONJ'), ('we', 'PRON'), ('kept', 'VERB'), ('it', 'PRON'), ('at', 'ADP'), ('that', 'DET'), ('', 'NOUN')]
# collocates around head in sentence: ['was', 'sara']
# was 0.9307166988329297
#
#
# soul
# [('the', 'DET'), ('soul', 'NOUN'), ('is', 'VERB'), ('forgiveness', 'ADV'), ('because', 'ADP'), ('it', 'PRON'), ('knows', 'VERB'), ('forgiveness', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'forgiveness']
# is 0.1284244279705442
#
#
# screen
# [('and', 'CONJ'), ('his', 'PRON'), ('screen', 'NOUN'), ('is', 'VERB'), ('stripes', 'NOUN'), ('and', 'CONJ'), ('he', 'PRON'), ('knows', 'VERB'), ('he', 'PRON'), ('saved', 'VERB'), ('his', 'PRON'), ('work', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.6452947489232962
#
#
# god
# [('god', 'NOUN'), ('was', 'VERB'), ('momentum', 'VERB'), ('then', 'ADV'), ('', 'VERB')]
# collocates around head in sentence: ['was', 'momentum']
# was -0.24373569456403915
#
#
# tank
# [('that', 'DET'), ('looks', 'VERB'), ('personal', 'ADJ'), ('', 'ADJ'), ('private', 'ADJ'), ('', 'NOUN'), ('this', 'DET'), ('tank', 'NOUN'), ('is', 'VERB'), ('nothing', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.594341390888898
#
#
# word
# [('what', 'PRON'), ('is', 'VERB'), ('the', 'DET'), ('world', 'NOUN'), ('', 'VERB'), ('the', 'DET'), ('word', 'NOUN'), ('is', 'VERB'), ('wilderness', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is', '', 'wilderness']
# is 0.46207309739373903
#
#
# answer
# [('what', 'PRON'), ('is', 'VERB'), ('the', 'DET'), ('answer', 'NOUN'), ('', 'VERB'), ('the', 'DET'), ('answer', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('world', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is', '']
# is 1.7766336660213147
#
#
# beginning
# [('what', 'PRON'), ('is', 'VERB'), ('the', 'DET'), ('beginning', 'VERB'), ('', 'PRT'), ('a', 'DET'), ('beginning', 'NOUN'), ('is', 'VERB'), ('happiness', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'happiness']
# is 0.6098742524830922
#
#
# paul
# [('paul', 'NOUN'), ('was', 'VERB'), ('the', 'DET'), ('sort', 'NOUN')]
# collocates around head in sentence: ['was']
# was 0.3167055759184926
#
#
# life
# [('a', 'DET'), ('father', 'NOUN'), ('tells', 'VERB'), ('his', 'PRON'), ('son', 'NOUN'), ('the', 'DET'), ('thing', 'NOUN'), ('he', 'PRON'), ('regrets', 'VERB'), ('most', 'ADJ'), ('about', 'ADP'), ('his', 'PRON'), ('life', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('amount', 'NOUN'), ('of', 'ADP'), ('time', 'NOUN'), ('he', 'PRON'), ('has', 'VERB'), ('spent', 'VERB'), ('worrying', 'VERB'), ('about', 'ADP'), ('it', 'PRON'), ('', 'VERB')]
# collocates around head in sentence: ['is']
# is 0.45217928334522717
#
#
# people
# [('those', 'DET'), ('people', 'NOUN'), ('were', 'VERB'), ('a', 'DET'), ('kind', 'NOUN'), ('of', 'ADP'), ('solution', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['were']
# were 1.7294839669501596
#
#
# it
# [('in', 'ADP'), ('the', 'DET'), ('star', 'NOUN'), ('', 'NOUN'), ('it', 'PRON'), ('is', 'VERB'), ('a', 'DET'), ('star', 'NOUN'), ('', 'NOUN'), ('it', 'PRON'), ('is', 'VERB'), ('autonomous', 'ADJ'), ('', 'NOUN'), ('', 'NOUN'), ('star', 'NOUN'), ('', 'VERB'), ('it', 'PRON'), ('s', 'VERB'), ('mild', 'ADJ'), ('', 'NOUN'), ('is', 'VERB')]
# collocates around head in sentence: ['is']
# is 2.364290732064418
#
#
# farm
# [('my', 'PRON'), ('father', 'NOUN'), ('s', 'NOUN'), ('farm', 'NOUN'), ('is', 'VERB'), ('an', 'DET'), ('apple', 'NOUN'), ('blossomer', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -1.061495913102035
#
#
# fields
# [('his', 'PRON'), ('fields', 'NOUN'), ('are', 'VERB'), ('oceans', 'NOUN'), ('of', 'ADP'), ('heat', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['are']
# are 1.0289577417569704
#
#
# farm
# [('my', 'PRON'), ('father', 'NOUN'), ('s', 'NOUN'), ('farm', 'NOUN'), ('is', 'VERB'), ('an', 'DET'), ('icicle', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -1.061495913102035
#
#
# today
# [('today', 'NOUN'), ('is', 'VERB'), ('friday', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is', 'friday']
# is 0.9916591865649264
#
#
# leg
# [('his', 'PRON'), ('left', 'VERB'), ('leg', 'NOUN'), ('was', 'VERB'), ('meal', 'ADJ'), ('', 'ADJ'), ('crayfish', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('hair', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['left', 'was', 'meal']
# left 4.047504103106504
# was -0.4160216917134683
#
#
# risk
# [('the', 'DET'), ('risk', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('part', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('rhythm', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.919664796625742
#
#
# hearing
# [('mentions', 'NOUN'), ('that', 'ADP'), ('hearing', 'NOUN'), ('is', 'VERB'), ('silver', 'ADJ')]
# collocates around head in sentence: ['is', 'silver']
# is -1.0644838914726071
#
#
# name
# [('the', 'DET'), ('name', 'NOUN'), ('is', 'VERB'), ('orestes', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.7423927627069589
#
#
# use
# [('no', 'DET'), ('one', 'NOUN'), ('can', 'VERB'), ('escape', 'VERB'), ('', 'VERB'), ('what', 'PRON'), ('use', 'NOUN'), ('is', 'VERB'), ('strength', 'NOUN'), ('', 'NOUN'), ('you', 'PRON'), ('ca', 'VERB'), ('nt', 'VERB')]
# collocates around head in sentence: ['is', '']
# is -0.703460798091022
#
#
# behind
# [('and', 'CONJ'), ('behind', 'NOUN'), ('was', 'VERB'), ('memory', 'NOUN'), ('like', 'ADP'), ('the', 'DET'), ('white', 'ADJ'), ('sheet', 'NOUN'), ('one', 'NUM'), ('night', 'NOUN'), ('in', 'ADP'), ('an', 'DET'), ('enclosure', 'NOUN')]
# collocates around head in sentence: ['was']
# was -0.2186950269865204
#
#
# perfume
# [('the', 'DET'), ('perfume', 'NOUN'), ('was', 'VERB'), ('flowers', 'NOUN'), ('ground', 'VERB'), ('upon', 'ADP'), ('stones', 'NOUN'), ('', 'NOUN')]
# collocates around head in sentence: ['was']
# was -1.377928520541394
#
#
# fish
# [('to', 'PRT'), ('cleanse', 'VERB'), ('our', 'PRON'), ('vision', 'NOUN'), ('', 'ADP'), ('the', 'DET'), ('fish', 'NOUN'), ('were', 'VERB'), ('silver', 'ADV'), ('', 'ADJ')]
# collocates around head in sentence: ['were', 'silver']
# were -0.08651458144023444
#
#
# martin
# [('martin', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('man', 'NOUN'), ('no', 'DET'), ('one', 'NOUN'), ('came', 'VERB'), ('close', 'ADV'), ('to', 'PRT'), ('knowing', 'VERB'), ('', 'NOUN')]
# collocates around head in sentence: ['was']
# was -1.0031113808454057
#
#
# singer
# [('was', 'VERB'), ('a', 'DET'), ('joke', 'NOUN'), ('because', 'ADP'), ('', 'X'), ('a', 'DET'), ('singer', 'NOUN'), ('is', 'VERB'), ('nothing', 'NOUN'), ('', 'ADJ'), ('', 'NOUN')]
# collocates around head in sentence: ['is']
# is -0.1710042151236489
#
#
# singer
# [('', 'VERB'), ('a', 'DET'), ('singer', 'NOUN'), ('is', 'VERB'), ('nothing', 'NOUN'), ('', 'ADJ'), ('', 'NOUN'), ('why', 'ADV'), ('did', 'VERB'), ('he', 'PRON'), ('sing', 'VERB'), ('', 'NOUN')]
# collocates around head in sentence: ['is', '']
# is -0.1710042151236489
#
#
# cold
# [('as', 'ADP'), ('the', 'DET'), ('season', 'NOUN'), ('of', 'ADP'), ('cold', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('season', 'NOUN'), ('of', 'ADP'), ('darkness', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.14887168163546904
#
#
# beasts
# [('else', 'ADV'), ('all', 'DET'), ('beasts', 'NOUN'), ('were', 'VERB'), ('tigers', 'NOUN'), ('', 'VERB')]
# collocates around head in sentence: ['were', 'else']
#
#
# earth
# [('without', 'ADP'), ('which', 'DET'), ('earth', 'NOUN'), ('is', 'VERB'), ('sand', 'NOUN')]
# collocates around head in sentence: ['is']
# is 0.027962357291987656
#
#
# sky
# [('the', 'DET'), ('sky', 'NOUN'), ('is', 'VERB'), ('cloud', 'VERB'), ('on', 'ADP'), ('cloud', 'NOUN')]
# collocates around head in sentence: ['is', 'cloud']
# is 0.11425969824394078
#
#
# sky
# [('the', 'DET'), ('sky', 'NOUN'), ('is', 'VERB'), ('cloudy', 'ADJ')]
# collocates around head in sentence: ['is', 'cloudy']
# is 0.11425969824394078
# cloudy 8.916163134578168

# %%
print(len(predictions))
print(len(isSentenceMetaphor))
# Out:
# 680
# 680

# %%
PredictedPositives = predictions.count('y')
PredictedNegatives = predictions.count('n')
TruePositives = 0
FalsePositives = 0
TrueNegatives = 0
FalseNegatives = 0

#Unknown results are skipped
for i in range(len(isSentenceMetaphor)):
    if predictions[i] == 'y' and isSentenceMetaphor[i] == 'y':
        TruePositives +=1
    elif predictions[i] == 'y' and isSentenceMetaphor[i] == 'n':
        FalsePositives += 1
    elif predictions[i] == 'n' and isSentenceMetaphor[i] == 'n':
        TrueNegatives += 1
    elif predictions[i] == 'n' and isSentenceMetaphor[i] == 'y':
        FalseNegatives += 1

#Disregards unknown classifications
Positives = TruePositives + FalseNegatives #Ground truth
Negatives = TrueNegatives + FalsePositives #Ground truth

print("Positives: " + str(Positives))
print("Negatives: " + str(Negatives))
print("Predicted positives: " + str(PredictedPositives))
print("Predicted negatives: " + str(PredictedNegatives))
print("TP: " + str(TruePositives))
print("FP: " + str(FalsePositives))
print("TN: " + str(TrueNegatives))
print("FN: " + str(FalseNegatives))
# Out:
# Positives: 327
# Negatives: 275
# Predicted positives: 592
# Predicted negatives: 10
# TP: 324
# FP: 268
# TN: 7
# FN: 3

# %%
accuracy = (TruePositives + TrueNegatives) / (Positives + Negatives)
print(accuracy)
precision = TruePositives / (TruePositives + FalsePositives)
print(precision)
recall = TruePositives / (TruePositives + FalseNegatives)
print(recall)
# Out:
# 0.5498338870431894
# 0.5472972972972973
# 0.9908256880733946
