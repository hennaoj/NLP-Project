# %%
import math
from nltk.corpus.reader.bnc import BNCCorpusReader
from nltk import FreqDist
import matplotlib.pyplot as plt
import re
import pickle

# %%
#Data structure for storing info of a collocate word
class CollocateWord:
    
    def __init__(self, collocate):
        self.collocate = collocate
        #Frequency of how often collocate word is found with word of interest
        self.collocateFrequency = 1
        #Will be calculated later with method call
        self.mutualInformation = None
        #Words count in corpus. Will be set later with method call
        self.corpusFrequency = None
        #Is the word positioned before of after the parent word in a sentence
        self.position = None #Not used yet

    def getWord(self):
        return self.collocate

    #Called in main each time the same word is found again
    def updateFrequency(self):
        self.collocateFrequency += 1

    def printMe(self):
        print("Collocate word: " + self.collocate)
        print("Frequency with parent word: " + str(self.collocateFrequency))
        print("Frequency in corpus: " + str(self.corpusFrequency))
        print("MI score: " + str(self.mutualInformation))

    def setMutualInformation(self, MI):
        self.mutualInformation = MI

    def setCorpusFrequency(self, freq):
        self.corpusFrequency = freq

# %%
#Data structure and logic for word under search and its collocates
class MutualInformationCalculator:
    
    def __init__(self, word, corpusSentences, corpusWords, span, sizeOfCorpus, freqDistribution):
        self.word = word
        self.frequency = 0
        self.collocates = []
        self.corpusSentences = corpusSentences
        self.corpusWords = corpusWords
        self.span = span
        self.sizeOfCorpus = sizeOfCorpus
        self.freqDistribution = freqDistribution

    def findCollocates(self):
        '''Find all collocate words around the word of interest'''    
        for sentence in self.corpusSentences:
            l_sentence = [(word_tuple[0].lower(), word_tuple[1] )for word_tuple in sentence]
            #if(l_sentence[0].count(self.word) == 0):
            #    continue
            #Should we remove stop words from search? Should be done here, at latest.
            for index, word in enumerate(l_sentence):
                #print(word[0].lower())
                #print(index)
                if word[0] == self.word:
                    self.updateFrequency()
                    self.findSpanningCollocations(l_sentence, index)
    
    def findSpanningCollocations(self, sentence, startingIndex,):
        '''When words of interest is found in the sentence, the sentence and index is passed here to find collocate words
        and updateCollocates is called for valid words to save them'''
        listOfIndexes = []
        #Assuming that the span = 3 in the task description actually means windows size instead, check only adjacent indexes.
        #  CURRENTLY FIXED WINDOW SIZE = 3
        indexesToTry = [startingIndex - 1, startingIndex + 1]
        for index in indexesToTry:
            if index >= 0 and index < len(sentence):
                word, wordType = sentence[index]
                #program should indentify only adjectives, adverbs and verbs
                if wordType == 'ADJ' or wordType == 'ADV' or wordType == "VERB":
                    self.updateCollocates(word)

    def updateCollocates(self, collocateWord):
        '''Checks if collocate is new to append it to list or to just update existing frequency'''
        #Check if collocate list is empty
        if self.collocates:
            for collocate in self.collocates:
                if collocate.getWord() == collocateWord:
                    collocate.updateFrequency()
                    return
                    
            self.collocates.append(CollocateWord(collocateWord))
        else:
            self.collocates.append(CollocateWord(collocateWord))
    
    #Used while searching collocate words.
    def updateFrequency(self):
        self.frequency += 1

    def calculateCollocateFrequencies(self):
        #Set the frequency in corpus for every collocate word
        for collocate in self.collocates:
            collocate.setCorpusFrequency(self.freqDistribution[collocate.getWord()])
            

    def printMe(self):
        print("Word of interest: " + self.word)
        print("Frequncy in corpus: " + str(self.frequency))
        print("Collocate words found: " + str(len(self.collocates)))

    def printCollocates(self):
        for collocate in self.collocates:
            collocate.printMe()

    def getCollocates(self):
        return self.collocates

    def calculateMutualInformations(self):
        '''Calculate MI for all collocate words. Requires that frequencies are calculated before running this.'''
        for collocate in self.collocates:
            MI = math.log10(( (collocate.collocateFrequency * self.sizeOfCorpus) / (self.frequency * collocate.corpusFrequency * self.span) ))
            MI = MI / math.log10(2)
            collocate.setMutualInformation(MI)

    def calculateAll(self):
        '''Does all calculation steps in one command.'''
        self.findCollocates()
        self.calculateCollocateFrequencies()
        self.calculateMutualInformations()
        self.removeCollocatesBelowFrequency(2)
        self.removeCollocatesBelowMI(3)

    def getCollacatesOverMiValue(self, limit):
        '''Return a list of collocates above wanted MI value'''
        return [collocate for collocate in self.collocates if (collocate.mutualInformation >= limit)]

    def getCollocatesOverFrequency(self, limit):
        return [collocate for collocate in self.collocates if (collocate.collocateFrequency >= limit)]

    def removeCollocatesBelowFrequency(self, limitFrequency):
        '''Remove collocates from object whose frequency with word of interest is lower than given limit.'''
        self.collocates[:] = [collocate for collocate in self.collocates if (collocate.collocateFrequency >= limitFrequency)]

    def removeCollocatesBelowMI(self, limitMI):
        self.collocates[:] = [collocate for collocate in self.collocates if (collocate.mutualInformation >= limitMI)]

    def sortCollocatesByFrequency(self):
        self.collocates.sort(key=lambda collocate: collocate.collocateFrequency, reverse=True)

    def sortCollocatesByMIscore(self):
        self.collocates.sort(key=lambda collocate: collocate.mutualInformation, reverse=True)

    def plotFrequencyFigure(self, xSize, ySize):
        miLim = 3
        fLim = 2
        #self.sortCollocatesByFrequency()
        words = [c.collocate for c in self.collocates]
        freqs = [c.collocateFrequency for c in self.collocates]
        fig, ax = plt.subplots(figsize = (xSize, ySize))
        ax.set_ylabel('Mutual frequency', fontsize=15)
        ax.set_title('Frequency of adjacent words from \'' + self.word + '\' with MI score >= ' + str(miLim) + ' and mutual frequency >= ' + str(fLim) + ')')
        ax.barh(words, freqs)
        plt.show()

    def plotMiFigure(self, xSize, ySize):
        miLim = 3
        fLim = 2
        self.sortCollocatesByMIscore()
        words = [c.collocate for c in self.collocates]
        mi_score = [c.mutualInformation for c in self.collocates]
        fig, ax = plt.subplots(figsize = (xSize, ySize))
        ax.set_ylabel('Mutual Information score', fontsize=15)
        ax.set_title('Mutual information score over ' + str(miLim) + ' with a word \'' + self.word + '\' and mutual frequency >= ' + str(fLim) + ')')
        ax.barh(words, mi_score)
        plt.show()

    def plotPresentationFigures(self):
        '''Plots only 25 top MI collocates, removes others'''
        self.collocates = self.collocates[:25]
        self.plotMiFigure(5,5)
        self.plotFrequencyFigure(5,5)

# %%
with open('sentsA.pkl', 'rb') as input:
    corpusSentences = pickle.load(input)

# %%
with open('wordsA.pkl', 'rb') as input:
    corpusWords = pickle.load(input)
#We want decapitalize words for easier handling
lower_words = [word.lower() for word in corpusWords]
sizeOfCorpus = len(lower_words)

# %%
#Calculate frequencies for all the words in corpus
fdist = FreqDist(lower_words)

# %%
'''
Formatting of the metaphor annotated corpus: http://aclweb.org/anthology/W/W17/W17-2201.pdf
Example: destroying alexandria . sunlight is silence @4@y
@-sign separates different fields
Sentece:                        destroying alexandria . sunlight is silence
Position of the head word       4 -> sunlight
Is the expression a metaphore?  y (yes), n (no), s (skipped)
'''
annotatedSentences = []
headWordPosition = []
isSentenceMetaphor = []
with open("type1_metaphor_annotated.txt") as textfile:
    for line in textfile: 
        line = line.split("@")
        if(line[2].strip() != 's'): #Exclude sentences which humans failed to classify
            annotatedSentences.append(line[0].strip())
            headWordPosition.append(line[1].strip())
            isSentenceMetaphor.append(line[2].strip())

'''
The dataset is quite problematic because the text is so unclean:
(
the night is each man 's castle . @2@y
swelling lukewarm ; her mouth is water , @5@y
& yet the earth is divinity , the sky is divinity @4@n
"i am the resurrection and the life . " @1@n
"how is the dean ? " -- "he 's just alive . " @1@n <-- especially problematic, because quotation mark is connected to the word
)
If all special characters are cleaned a way, the head word
position tag may change, and we cannot reliably verify the algorithm.
If not cleaned, the some words are left unrecognized...
'''
# Out:
# '\nThe dataset is quite problematic because the text is so unclean:\n(\nthe night is each man \'s castle . @2@y\nswelling lukewarm ; her mouth is water , @5@y\n& yet the earth is divinity , the sky is divinity @4@n\n"i am the resurrection and the life . " @1@n\n"how is the dean ? " -- "he \'s just alive . " @1@n <-- especially problematic, because quotation mark is connected to the word\n)\nIf all special characters are cleaned a way, the head word\nposition tag may change, and we cannot reliably verify the algorithm.\nIf not cleaned, the some words are left unrecognized...\n'

# %%
def getCollocatesAroundHead(sentence, index, span):
    collocates = []
    i = 1
    while(span > 0):
        if(index - i >= 0):
            collocates.append(sentence[index -i])
        
        if(index + i <= len(sentence)):
            collocates.append(sentence[index + i])
        i +=1
        span -= 1
    #print(collocates)
    return collocates

# %%
span = 2

# %%
predictions = []
for i in range(len(headWordPosition)):
    #print(annotatedSentences[i])
    sentence = annotatedSentences[i].split()
    headWordIndex =int(headWordPosition[i])-1
    
    
    sentence = [re.sub(r'[^a-zA-Z ]', '', word) for word in sentence]
    sentence[:] = [word.strip() for word in sentence]
    headWord = sentence[headWordIndex].lower()
    #sentence[:] = [word for word in sentence if word] #this will mess up the head word indexing
    #print(sentence)
    #print(headWord)

    MutualInformation = MutualInformationCalculator(headWord, corpusSentences, lower_words, span, sizeOfCorpus, fdist)
    MutualInformation.findCollocates()
    MutualInformation.calculateCollocateFrequencies()
    MutualInformation.calculateMutualInformations()
    #TODO: select frequency cutoff
    MutualInformation.printMe()

    corpusCollocates = MutualInformation.getCollocates()

    #TODO: get only adj, adv, verb?
    collocates = getCollocatesAroundHead(sentence, headWordIndex, span)
    
    matchingCollocates = []
    for collocate in collocates:
        for corpCollocate in corpusCollocates:
            if collocate == corpCollocate.getWord():
                matchingCollocates.append(corpCollocate)

    #for c in matchingCollocates:
    #    c.printMe()
    isMetaphor = None

    for c in matchingCollocates:
        if c.mutualInformation > 2.5:
            isMetaphor = False
    if isMetaphor == False:
        predictions.append('n')
    else:
        predictions.append('y')
# Out:
# poise is a club .
# ['poise', 'is', 'a', 'club', '']
# poise
# Word of interest: poise
# Frequncy in corpus: 27
# Collocate words found: 14
# ['is', 'a']
# Collocate word: is
# Frequency with parent word: 1
# Frequency in corpus: 142373
# MI score: 1.0386096014914963
# destroying alexandria . sunlight is silence
# ['destroying', 'alexandria', '', 'sunlight', 'is', 'silence']
# sunlight
# Word of interest: sunlight
# Frequncy in corpus: 174
# Collocate words found: 75
# ['', 'is', 'alexandria', 'silence']
# Collocate word: is
# Frequency with parent word: 5
# Frequency in corpus: 142373
# MI score: 0.6724817026935989
# feet are no anchor . gravity sucks at the mind
# ['feet', 'are', 'no', 'anchor', '', 'gravity', 'sucks', 'at', 'the', 'mind']
# feet
# Word of interest: feet
# Frequncy in corpus: 2330
# Collocate words found: 514
# ['are', 'no']
# Collocate word: are
# Frequency with parent word: 31
# Frequency in corpus: 64818
# MI score: 0.6967883389667018
# on the day 's horizon is a gesture of earth
# ['on', 'the', 'day', 's', 'horizon', 'is', 'a', 'gesture', 'of', 'earth']
# horizon
# Word of interest: horizon
# Frequncy in corpus: 228
# Collocate words found: 51
# ['s', 'is', 'day', 'a']
# Collocate word: is
# Frequency with parent word: 13
# Frequency in corpus: 142373
# MI score: 1.6610468076313152
# he said good-by as if good-by is a number .
# ['he', 'said', 'goodby', 'as', 'if', 'goodby', 'is', 'a', 'number', '']
# goodby
# Word of interest: goodby
# Frequncy in corpus: 0
# Collocate words found: 0
# ['if', 'is', 'as', 'a']
# although your eyes be lakes , dies
# ['although', 'your', 'eyes', 'be', 'lakes', '', 'dies']
# eyes
# Word of interest: eyes
# Frequncy in corpus: 3153
# Collocate words found: 673
# ['your', 'be', 'although', 'lakes']
# ways ! as if the world were a taxi , you enter it , then
# ['ways', '', 'as', 'if', 'the', 'world', 'were', 'a', 'taxi', '', 'you', 'enter', 'it', '', 'then']
# world
# Word of interest: world
# Frequncy in corpus: 10887
# Collocate words found: 1212
# ['the', 'were', 'if', 'a']
# Collocate word: were
# Frequency with parent word: 14
# Frequency in corpus: 45600
# MI score: -2.1668969703282905
# the poet is a man who feigns
# ['the', 'poet', 'is', 'a', 'man', 'who', 'feigns']
# poet
# Word of interest: poet
# Frequncy in corpus: 624
# Collocate words found: 208
# ['the', 'is', 'a']
# Collocate word: is
# Frequency with parent word: 9
# Frequency in corpus: 142373
# MI score: -0.32198011376497104
# man is an animal that needs a warden
# ['man', 'is', 'an', 'animal', 'that', 'needs', 'a', 'warden']
# man
# Word of interest: man
# Frequncy in corpus: 8897
# Collocate words found: 1612
# ['is', 'an']
# Collocate word: is
# Frequency with parent word: 171
# Frequency in corpus: 142373
# MI score: 0.09224638147829975
# my name is james a . wright , and i was born
# ['my', 'name', 'is', 'james', 'a', '', 'wright', '', 'and', 'i', 'was', 'born']
# name
# Word of interest: name
# Frequncy in corpus: 3448
# Collocate words found: 410
# ['my', 'is', 'james']
# Collocate word: is
# Frequency with parent word: 143
# Frequency in corpus: 142373
# MI score: 1.201824381344256
# earth is a door i cannot even face .
# ['earth', 'is', 'a', 'door', 'i', 'cannot', 'even', 'face', '']
# earth
# Word of interest: earth
# Frequncy in corpus: 1360
# Collocate words found: 236
# ['is', 'a']
# Collocate word: is
# Frequency with parent word: 38
# Frequency in corpus: 142373
# MI score: 0.6320336809608486
# the hackles on my neck are fear , not grief .
# ['the', 'hackles', 'on', 'my', 'neck', 'are', 'fear', '', 'not', 'grief', '']
# neck
# Word of interest: neck
# Frequncy in corpus: 658
# Collocate words found: 113
# ['my', 'are', 'on', 'fear']
# Collocate word: are
# Frequency with parent word: 4
# Frequency in corpus: 64818
# MI score: -0.43323750561377217
# the moon is a sow
# ['the', 'moon', 'is', 'a', 'sow']
# moon
# Word of interest: moon
# Frequncy in corpus: 398
# Collocate words found: 89
# ['the', 'is', 'a']
# Collocate word: is
# Frequency with parent word: 7
# Frequency in corpus: 142373
# MI score: -0.03577259483107999
# "earth is the birth of the blues , " sang yellow bertha ,
# ['earth', 'is', 'the', 'birth', 'of', 'the', 'blues', '', '', 'sang', 'yellow', 'bertha', '']
# earth
# Word of interest: earth
# Frequncy in corpus: 1360
# Collocate words found: 236
# ['is', 'the']
# Collocate word: is
# Frequency with parent word: 38
# Frequency in corpus: 142373
# MI score: 0.6320336809608486
# about the nature of understanding . no one is that simple
# ['about', 'the', 'nature', 'of', 'understanding', '', 'no', 'one', 'is', 'that', 'simple']
# one
# Word of interest: one
# Frequncy in corpus: 39618
# Collocate words found: 3687
# ['no', 'is', '', 'that']
# Collocate word: no
# Frequency with parent word: 22
# Frequency in corpus: 26841
# MI score: -2.613774460706871
# Collocate word: is
# Frequency with parent word: 1963
# Frequency in corpus: 142373
# MI score: 1.4584731297872662
# Collocate word: that
# Frequency with parent word: 125
# Frequency in corpus: 139498
# MI score: -2.4851559054608536
# the real terror of nature is humanity enraged , the true
# ['the', 'real', 'terror', 'of', 'nature', 'is', 'humanity', 'enraged', '', 'the', 'true']
# nature
# Word of interest: nature
# Frequncy in corpus: 2602
# Collocate words found: 650
# ['of', 'is', 'terror', 'humanity']
# Collocate word: is
# Frequency with parent word: 62
# Frequency in corpus: 142373
# MI score: 0.40228816732404477
# love is a word another kind of open --
# ['love', 'is', 'a', 'word', 'another', 'kind', 'of', 'open', '']
# love
# Word of interest: love
# Frequncy in corpus: 3232
# Collocate words found: 446
# ['is', 'a']
# Collocate word: is
# Frequency with parent word: 73
# Frequency in corpus: 142373
# MI score: 0.3251101797831874
# your goodbye is a promise of lightning
# ['your', 'goodbye', 'is', 'a', 'promise', 'of', 'lightning']
# goodbye
# Word of interest: goodbye
# Frequncy in corpus: 241
# Collocate words found: 34
# ['your', 'is', 'a']
# Collocate word: is
# Frequency with parent word: 1
# Frequency in corpus: 142373
# MI score: -2.1193922325749965
# his broken body is the afterimage of my 21st year
# ['his', 'broken', 'body', 'is', 'the', 'afterimage', 'of', 'my', 'st', 'year']
# body
# Word of interest: body
# Frequncy in corpus: 3654
# Collocate words found: 764
# ['broken', 'is', 'his', 'the']
# Collocate word: broken
# Frequency with parent word: 6
# Frequency in corpus: 1054
# MI score: 3.6208555842105152
# Collocate word: is
# Frequency with parent word: 103
# Frequency in corpus: 142373
# MI score: 0.6447367122106946
# my eyes are caves , chunks of etched rock
# ['my', 'eyes', 'are', 'caves', '', 'chunks', 'of', 'etched', 'rock']
# eyes
# Word of interest: eyes
# Frequncy in corpus: 3153
# Collocate words found: 673
# ['my', 'are', 'caves']
# Collocate word: are
# Frequency with parent word: 63
# Frequency in corpus: 64818
# MI score: 1.283476736938051
# the sky is baby blue , and the just-unfurling leaves
# ['the', 'sky', 'is', 'baby', 'blue', '', 'and', 'the', 'justunfurling', 'leaves']
# sky
# Word of interest: sky
# Frequncy in corpus: 743
# Collocate words found: 174
# ['the', 'is', 'baby']
# Collocate word: is
# Frequency with parent word: 23
# Frequency in corpus: 142373
# MI score: 0.7798406591733814
# down the road is somebody small on the shoulder ,
# ['down', 'the', 'road', 'is', 'somebody', 'small', 'on', 'the', 'shoulder', '']
# road
# Word of interest: road
# Frequncy in corpus: 3902
# Collocate words found: 462
# ['the', 'is', 'down', 'somebody']
# Collocate word: is
# Frequency with parent word: 45
# Frequency in corpus: 142373
# MI score: -0.6446478626243868
# Collocate word: down
# Frequency with parent word: 4
# Frequency in corpus: 12860
# MI score: -0.667787931070274
# i wrote life was a strain . later , someone crossed it out .
# ['i', 'wrote', 'life', 'was', 'a', 'strain', '', 'later', '', 'someone', 'crossed', 'it', 'out', '']
# life
# Word of interest: life
# Frequncy in corpus: 9588
# Collocate words found: 1149
# ['wrote', 'was', 'i', 'a']
# Collocate word: wrote
# Frequency with parent word: 2
# Frequency in corpus: 2725
# MI score: -0.726241554446722
# Collocate word: was
# Frequency with parent word: 215
# Frequency in corpus: 131558
# MI score: 0.4286523542611818
# it is clear that mr . haggard is ryder 's brother !
# ['it', 'is', 'clear', 'that', 'mr', '', 'haggard', 'is', 'ryder', 's', 'brother', '']
# haggard
# Word of interest: haggard
# Frequncy in corpus: 20
# Collocate words found: 12
# ['', 'is', 'mr', 'ryder']
# the mind is a city like london ,
# ['the', 'mind', 'is', 'a', 'city', 'like', 'london', '']
# mind
# Word of interest: mind
# Frequncy in corpus: 3840
# Collocate words found: 502
# ['the', 'is', 'a']
# Collocate word: is
# Frequency with parent word: 83
# Frequency in corpus: 142373
# MI score: 0.261645939393371
# -- the others were the despots of despair --
# ['', 'the', 'others', 'were', 'the', 'despots', 'of', 'despair', '']
# others
# Word of interest: others
# Frequncy in corpus: 4250
# Collocate words found: 733
# ['the', 'were', '', 'the']
# Collocate word: were
# Frequency with parent word: 159
# Frequency in corpus: 45600
# MI score: 2.695702779186525
# knowing intuitively how a sense of humor was a necessity
# ['knowing', 'intuitively', 'how', 'a', 'sense', 'of', 'humor', 'was', 'a', 'necessity']
# humor
# Word of interest: humor
# Frequncy in corpus: 5
# Collocate words found: 1
# ['of', 'was', 'sense', 'a']
# your guilt is nameless , because its name is time ,
# ['your', 'guilt', 'is', 'nameless', '', 'because', 'its', 'name', 'is', 'time', '']
# name
# Word of interest: name
# Frequncy in corpus: 3448
# Collocate words found: 410
# ['its', 'is', 'because', 'time']
# Collocate word: is
# Frequency with parent word: 143
# Frequency in corpus: 142373
# MI score: 1.201824381344256
# because its name is death . but you can stop
# ['because', 'its', 'name', 'is', 'death', '', 'but', 'you', 'can', 'stop']
# name
# Word of interest: name
# Frequncy in corpus: 3448
# Collocate words found: 410
# ['its', 'is', 'because', 'death']
# Collocate word: is
# Frequency with parent word: 143
# Frequency in corpus: 142373
# MI score: 1.201824381344256
# hamlet is the example ; only dying
# ['hamlet', 'is', 'the', 'example', '', 'only', 'dying']
# hamlet
# Word of interest: hamlet
# Frequncy in corpus: 135
# Collocate words found: 48
# ['is', 'the']
# Collocate word: is
# Frequency with parent word: 1
# Frequency in corpus: 142373
# MI score: -1.2833184933958661
# the sun is a yellowjacket
# ['the', 'sun', 'is', 'a', 'yellowjacket']
# sun
# Word of interest: sun
# Frequncy in corpus: 1565
# Collocate words found: 300
# ['the', 'is', 'a']
# Collocate word: is
# Frequency with parent word: 50
# Frequency in corpus: 142373
# MI score: 0.8254063516097088
# love is a fiction i must use ,
# ['love', 'is', 'a', 'fiction', 'i', 'must', 'use', '']
# love
# Word of interest: love
# Frequncy in corpus: 3232
# Collocate words found: 446
# ['is', 'a']
# Collocate word: is
# Frequency with parent word: 73
# Frequency in corpus: 142373
# MI score: 0.3251101797831874
# and people are home for the homecomings .
# ['and', 'people', 'are', 'home', 'for', 'the', 'homecomings', '']
# people
# Word of interest: people
# Frequncy in corpus: 17886
# Collocate words found: 2603
# ['and', 'are', 'home']
# Collocate word: are
# Frequency with parent word: 746
# Frequency in corpus: 64818
# MI score: 2.3451949276643815
# Collocate word: home
# Frequency with parent word: 1
# Frequency in corpus: 7555
# MI score: -4.096946047010454
# yet life is the invocation sealed in the coffin ,
# ['yet', 'life', 'is', 'the', 'invocation', 'sealed', 'in', 'the', 'coffin', '']
# life
# Word of interest: life
# Frequncy in corpus: 9588
# Collocate words found: 1149
# ['yet', 'is', 'the']
# Collocate word: yet
# Frequency with parent word: 1
# Frequency in corpus: 5821
# MI score: -2.821252342142987
# Collocate word: is
# Frequency with parent word: 346
# Frequency in corpus: 142373
# MI score: 1.0011111376425565
# this swift darkness is spring 's first hour .
# ['this', 'swift', 'darkness', 'is', 'spring', 's', 'first', 'hour', '']
# darkness
# Word of interest: darkness
# Frequncy in corpus: 472
# Collocate words found: 110
# ['swift', 'is', 'this', 'spring']
# Collocate word: is
# Frequency with parent word: 3
# Frequency in corpus: 142373
# MI score: -1.5041834449857203
# the trees are crystal chandeliers ,
# ['the', 'trees', 'are', 'crystal', 'chandeliers', '']
# trees
# Word of interest: trees
# Frequncy in corpus: 1545
# Collocate words found: 402
# ['the', 'are', 'crystal']
# Collocate word: are
# Frequency with parent word: 37
# Frequency in corpus: 64818
# MI score: 1.5447685109586822
# but still the branches are wire
# ['but', 'still', 'the', 'branches', 'are', 'wire']
# branches
# Word of interest: branches
# Frequncy in corpus: 597
# Collocate words found: 237
# ['the', 'are', 'still', 'wire']
# Collocate word: are
# Frequency with parent word: 8
# Frequency in corpus: 64818
# MI score: 0.7071191468566642
# Collocate word: still
# Frequency with parent word: 1
# Frequency in corpus: 11237
# MI score: 0.23525672973122594
# the deer are ghosts who slip between the light
# ['the', 'deer', 'are', 'ghosts', 'who', 'slip', 'between', 'the', 'light']
# deer
# Word of interest: deer
# Frequncy in corpus: 196
# Collocate words found: 66
# ['the', 'are', 'ghosts']
# Collocate word: are
# Frequency with parent word: 1
# Frequency in corpus: 64818
# MI score: -0.6860035759937392
# the gray snow in the cemetery was sheet tin . if i said
# ['the', 'gray', 'snow', 'in', 'the', 'cemetery', 'was', 'sheet', 'tin', '', 'if', 'i', 'said']
# cemetery
# Word of interest: cemetery
# Frequncy in corpus: 118
# Collocate words found: 34
# ['the', 'was', 'in', 'sheet']
# Collocate word: was
# Frequency with parent word: 5
# Frequency in corpus: 131558
# MI score: 1.3467587438463755
# and spades are spades and clubs are clovers ?black .
# ['and', 'spades', 'are', 'spades', 'and', 'clubs', 'are', 'clovers', 'black', '']
# spades
# Word of interest: spades
# Frequncy in corpus: 36
# Collocate words found: 14
# ['and', 'are', 'spades']
# Collocate word: are
# Frequency with parent word: 3
# Frequency in corpus: 64818
# MI score: 3.343743767400313
# and spades are spades and clubs are clovers ?black .
# ['and', 'spades', 'are', 'spades', 'and', 'clubs', 'are', 'clovers', 'black', '']
# clubs
# Word of interest: clubs
# Frequncy in corpus: 764
# Collocate words found: 271
# ['and', 'are', 'spades', 'clovers']
# Collocate word: are
# Frequency with parent word: 20
# Frequency in corpus: 64818
# MI score: 1.6732055349730826
# the lean monk-copyist who scribes the books is slate-blue at his fingertips
# ['the', 'lean', 'monkcopyist', 'who', 'scribes', 'the', 'books', 'is', 'slateblue', 'at', 'his', 'fingertips']
# books
# Word of interest: books
# Frequncy in corpus: 1977
# Collocate words found: 458
# ['the', 'is', 'scribes', 'slateblue']
# Collocate word: is
# Frequency with parent word: 21
# Frequency in corpus: 142373
# MI score: -0.7632826292954827
# whose talisman is a phoenix
# ['whose', 'talisman', 'is', 'a', 'phoenix']
# talisman
# Word of interest: talisman
# Frequncy in corpus: 9
# Collocate words found: 3
# ['whose', 'is', 'a']
# whose emblem is the rock of gibraltar --
# ['whose', 'emblem', 'is', 'the', 'rock', 'of', 'gibraltar', '']
# emblem
# Word of interest: emblem
# Frequncy in corpus: 49
# Collocate words found: 18
# ['whose', 'is', 'the']
# Collocate word: is
# Frequency with parent word: 2
# Frequency in corpus: 142373
# MI score: 1.1787872595397566
# machines are the animals of the americans --
# ['machines', 'are', 'the', 'animals', 'of', 'the', 'americans', '']
# machines
# Word of interest: machines
# Frequncy in corpus: 516
# Collocate words found: 212
# ['are', 'the']
# Collocate word: are
# Frequency with parent word: 27
# Frequency in corpus: 64818
# MI score: 2.6723665148616833
# man is a speech
# ['man', 'is', 'a', 'speech']
# man
# Word of interest: man
# Frequncy in corpus: 8897
# Collocate words found: 1612
# ['is', 'a']
# Collocate word: is
# Frequency with parent word: 171
# Frequency in corpus: 142373
# MI score: 0.09224638147829975
# where books were trees .
# ['where', 'books', 'were', 'trees', '']
# books
# Word of interest: books
# Frequncy in corpus: 1977
# Collocate words found: 458
# ['where', 'were', 'trees']
# Collocate word: where
# Frequency with parent word: 1
# Frequency in corpus: 14021
# MI score: -1.8115856298454576
# Collocate word: were
# Frequency with parent word: 47
# Frequency in corpus: 45600
# MI score: 2.0415586457630255
# where trees were books .
# ['where', 'trees', 'were', 'books', '']
# trees
# Word of interest: trees
# Frequncy in corpus: 1545
# Collocate words found: 402
# ['where', 'were', 'books']
# Collocate word: where
# Frequency with parent word: 1
# Frequency in corpus: 14021
# MI score: -1.4558795969079865
# Collocate word: were
# Frequency with parent word: 32
# Frequency in corpus: 45600
# MI score: 1.8426758270228587
# underwear is something
# ['underwear', 'is', 'something']
# underwear
# Word of interest: underwear
# Frequncy in corpus: 69
# Collocate words found: 31
# ['is', 'something']
# john henry was a man just six feet high ,
# ['john', 'henry', 'was', 'a', 'man', 'just', 'six', 'feet', 'high', '']
# henry
# Word of interest: henry
# Frequncy in corpus: 1800
# Collocate words found: 338
# ['john', 'was', 'a']
# Collocate word: was
# Frequency with parent word: 65
# Frequency in corpus: 131558
# MI score: 1.1160603201322716
# " a man is nothing but a man ,
# ['', 'a', 'man', 'is', 'nothing', 'but', 'a', 'man', '']
# man
# Word of interest: man
# Frequncy in corpus: 8897
# Collocate words found: 1612
# ['a', 'is', '', 'nothing']
# Collocate word: is
# Frequency with parent word: 171
# Frequency in corpus: 142373
# MI score: 0.09224638147829975
# his heart was all a-flutter .
# ['his', 'heart', 'was', 'all', 'aflutter', '']
# heart
# Word of interest: heart
# Frequncy in corpus: 2116
# Collocate words found: 340
# ['his', 'was', 'all']
# Collocate word: was
# Frequency with parent word: 42
# Frequency in corpus: 131558
# MI score: 0.25266720898558903
# Collocate word: all
# Frequency with parent word: 2
# Frequency in corpus: 38604
# MI score: -2.370773479733858
# lifted , as we say , since words are a weight , and music .
# ['lifted', '', 'as', 'we', 'say', '', 'since', 'words', 'are', 'a', 'weight', '', 'and', 'music', '']
# words
# Word of interest: words
# Frequncy in corpus: 2669
# Collocate words found: 601
# ['since', 'are', '', 'a']
# Collocate word: are
# Frequency with parent word: 58
# Frequency in corpus: 64818
# MI score: 1.404603673107075
# in vapor was the ocean 's presence , ghost
# ['in', 'vapor', 'was', 'the', 'ocean', 's', 'presence', '', 'ghost']
# vapor
# Word of interest: vapor
# Frequncy in corpus: 0
# Collocate words found: 0
# ['in', 'was', 'the']
# what use are books to me
# ['what', 'use', 'are', 'books', 'to', 'me']
# use
# Word of interest: use
# Frequncy in corpus: 7361
# Collocate words found: 821
# ['what', 'are', 'books']
# Collocate word: are
# Frequency with parent word: 10
# Frequency in corpus: 64818
# MI score: -2.595051692968233
# to them lead floats , a leaf sinks . their god is the size
# ['to', 'them', 'lead', 'floats', '', 'a', 'leaf', 'sinks', '', 'their', 'god', 'is', 'the', 'size']
# god
# Word of interest: god
# Frequncy in corpus: 4442
# Collocate words found: 621
# ['their', 'is', '', 'the']
# Collocate word: is
# Frequency with parent word: 262
# Frequency in corpus: 142373
# MI score: 1.7099264276454345
# the night is each man 's castle .
# ['the', 'night', 'is', 'each', 'man', 's', 'castle', '']
# night
# Word of interest: night
# Frequncy in corpus: 5014
# Collocate words found: 527
# ['the', 'is', 'each']
# Collocate word: is
# Frequency with parent word: 27
# Frequency in corpus: 142373
# MI score: -1.7433616750155057
# Collocate word: each
# Frequency with parent word: 32
# Frequency in corpus: 7911
# MI score: 2.6714225163344065
# that all recurring joy is pain refined ,
# ['that', 'all', 'recurring', 'joy', 'is', 'pain', 'refined', '']
# joy
# Word of interest: joy
# Frequncy in corpus: 569
# Collocate words found: 137
# ['recurring', 'is', 'all', 'pain']
# Collocate word: is
# Frequency with parent word: 15
# Frequency in corpus: 142373
# MI score: 0.5481028569569014
# in june the sun is a bonnet of light
# ['in', 'june', 'the', 'sun', 'is', 'a', 'bonnet', 'of', 'light']
# sun
# Word of interest: sun
# Frequncy in corpus: 1565
# Collocate words found: 300
# ['the', 'is', 'june', 'a']
# Collocate word: is
# Frequency with parent word: 50
# Frequency in corpus: 142373
# MI score: 0.8254063516097088
# this afternoon was the colour of water falling through sunlight ;
# ['this', 'afternoon', 'was', 'the', 'colour', 'of', 'water', 'falling', 'through', 'sunlight', '']
# afternoon
# Word of interest: afternoon
# Frequncy in corpus: 1152
# Collocate words found: 156
# ['this', 'was', 'the']
# Collocate word: this
# Frequency with parent word: 180
# Frequency in corpus: 60183
# MI score: 4.357672845218203
# Collocate word: was
# Frequency with parent word: 7
# Frequency in corpus: 131558
# MI score: -1.4550963810638537
# of hills is a kind of waiting .
# ['of', 'hills', 'is', 'a', 'kind', 'of', 'waiting', '']
# hills
# Word of interest: hills
# Frequncy in corpus: 551
# Collocate words found: 154
# ['of', 'is', 'a']
# Collocate word: is
# Frequency with parent word: 3
# Frequency in corpus: 142373
# MI score: -1.7274489041950365
# if the world is a dream ,
# ['if', 'the', 'world', 'is', 'a', 'dream', '']
# world
# Word of interest: world
# Frequncy in corpus: 10887
# Collocate words found: 1212
# ['the', 'is', 'if', 'a']
# Collocate word: is
# Frequency with parent word: 186
# Frequency in corpus: 142373
# MI score: -0.0776629274374942
# and the rich in connecticut are dreamers .
# ['and', 'the', 'rich', 'in', 'connecticut', 'are', 'dreamers', '']
# connecticut
# Word of interest: connecticut
# Frequncy in corpus: 25
# Collocate words found: 3
# ['in', 'are', 'rich', 'dreamers']
# swelling lukewarm ; her mouth is water ,
# ['swelling', 'lukewarm', '', 'her', 'mouth', 'is', 'water', '']
# mouth
# Word of interest: mouth
# Frequncy in corpus: 1038
# Collocate words found: 208
# ['her', 'is', '', 'water']
# Collocate word: is
# Frequency with parent word: 15
# Frequency in corpus: 142373
# MI score: -0.3192030290943976
# how can i tell you my mind is a blanket ?
# ['how', 'can', 'i', 'tell', 'you', 'my', 'mind', 'is', 'a', 'blanket', '']
# mind
# Word of interest: mind
# Frequncy in corpus: 3840
# Collocate words found: 502
# ['my', 'is', 'you', 'a']
# Collocate word: is
# Frequency with parent word: 83
# Frequency in corpus: 142373
# MI score: 0.261645939393371
# what i like about impermanence is the clash
# ['what', 'i', 'like', 'about', 'impermanence', 'is', 'the', 'clash']
# impermanence
# Word of interest: impermanence
# Frequncy in corpus: 1
# Collocate words found: 0
# ['about', 'is', 'like', 'the']
# that nighttime & meditation are a mirage
# ['that', 'nighttime', '', 'meditation', 'are', 'a', 'mirage']
# meditation
# Word of interest: meditation
# Frequncy in corpus: 72
# Collocate words found: 29
# ['', 'are', 'nighttime', 'a']
# & yet the earth is divinity , the sky is divinity
# ['', 'yet', 'the', 'earth', 'is', 'divinity', '', 'the', 'sky', 'is', 'divinity']
# earth
# Word of interest: earth
# Frequncy in corpus: 1360
# Collocate words found: 236
# ['the', 'is', 'yet', 'divinity']
# Collocate word: is
# Frequency with parent word: 38
# Frequency in corpus: 142373
# MI score: 0.6320336809608486
# & yet the earth is divinity , the sky is divinity
# ['', 'yet', 'the', 'earth', 'is', 'divinity', '', 'the', 'sky', 'is', 'divinity']
# sky
# Word of interest: sky
# Frequncy in corpus: 743
# Collocate words found: 174
# ['the', 'is', '', 'divinity']
# Collocate word: is
# Frequency with parent word: 23
# Frequency in corpus: 142373
# MI score: 0.7798406591733814
# which constant spirits are the keepers of ,
# ['which', 'constant', 'spirits', 'are', 'the', 'keepers', 'of', '']
# spirits
# Word of interest: spirits
# Frequncy in corpus: 262
# Collocate words found: 85
# ['constant', 'are', 'which', 'the']
# Collocate word: are
# Frequency with parent word: 5
# Frequency in corpus: 64818
# MI score: 1.2172113614713813
# mine was the scene
# ['mine', 'was', 'the', 'scene']
# mine
# Word of interest: mine
# Frequncy in corpus: 593
# Collocate words found: 145
# ['was', 'the']
# Collocate word: was
# Frequency with parent word: 28
# Frequency in corpus: 131558
# MI score: 1.5029403258324547
# but the breeze of dawn is the angel of death .
# ['but', 'the', 'breeze', 'of', 'dawn', 'is', 'the', 'angel', 'of', 'death', '']
# dawn
# Word of interest: dawn
# Frequncy in corpus: 401
# Collocate words found: 88
# ['of', 'is', 'breeze', 'the']
# Collocate word: is
# Frequency with parent word: 3
# Frequency in corpus: 142373
# MI score: -1.2689988220787993
# you ca n't get lost . home is the place they cross .
# ['you', 'ca', 'nt', 'get', 'lost', '', 'home', 'is', 'the', 'place', 'they', 'cross', '']
# home
# Word of interest: home
# Frequncy in corpus: 7555
# Collocate words found: 776
# ['', 'is', 'lost', 'the']
# Collocate word: is
# Frequency with parent word: 106
# Frequency in corpus: 142373
# MI score: -0.3617984818340276
# Collocate word: lost
# Frequency with parent word: 1
# Frequency in corpus: 3184
# MI score: -1.6070275068417783
# and he was a maker , his sausage was echt
# ['and', 'he', 'was', 'a', 'maker', '', 'his', 'sausage', 'was', 'echt']
# sausage
# Word of interest: sausage
# Frequncy in corpus: 85
# Collocate words found: 29
# ['his', 'was', '', 'echt']
# i learned what the selves are a man can disown
# ['i', 'learned', 'what', 'the', 'selves', 'are', 'a', 'man', 'can', 'disown']
# selves
# Word of interest: selves
# Frequncy in corpus: 48
# Collocate words found: 31
# ['the', 'are', 'what', 'a']
# Collocate word: are
# Frequency with parent word: 1
# Frequency in corpus: 64818
# MI score: 1.3437437674003132
# see shopping is an art form
# ['see', 'shopping', 'is', 'an', 'art', 'form']
# shopping
# Word of interest: shopping
# Frequncy in corpus: 514
# Collocate words found: 133
# ['see', 'is', 'an']
# Collocate word: is
# Frequency with parent word: 3
# Frequency in corpus: 142373
# MI score: -1.6271649448177572
# my only other callers were the fbi
# ['my', 'only', 'other', 'callers', 'were', 'the', 'fbi']
# callers
# Word of interest: callers
# Frequncy in corpus: 33
# Collocate words found: 21
# ['other', 'were', 'only', 'the']
# Collocate word: other
# Frequency with parent word: 1
# Frequency in corpus: 20929
# MI score: 3.5152032744282056
# Collocate word: only
# Frequency with parent word: 1
# Frequency in corpus: 22681
# MI score: 3.3992224050758773
# if you are with them , if even mind is friend ,
# ['if', 'you', 'are', 'with', 'them', '', 'if', 'even', 'mind', 'is', 'friend', '']
# mind
# Word of interest: mind
# Frequncy in corpus: 3840
# Collocate words found: 502
# ['even', 'is', 'if', 'friend']
# Collocate word: even
# Frequency with parent word: 7
# Frequency in corpus: 14822
# MI score: -0.042175029540899134
# Collocate word: is
# Frequency with parent word: 83
# Frequency in corpus: 142373
# MI score: 0.261645939393371
# of my window and survive ( the body is no illusion
# ['of', 'my', 'window', 'and', 'survive', '', 'the', 'body', 'is', 'no', 'illusion']
# body
# Word of interest: body
# Frequncy in corpus: 3654
# Collocate words found: 764
# ['the', 'is', '', 'no']
# Collocate word: is
# Frequency with parent word: 103
# Frequency in corpus: 142373
# MI score: 0.6447367122106946
# Collocate word: no
# Frequency with parent word: 1
# Frequency in corpus: 26841
# MI score: -3.634598566637788
# this crushing of people is something we live with .
# ['this', 'crushing', 'of', 'people', 'is', 'something', 'we', 'live', 'with', '']
# people
# Word of interest: people
# Frequncy in corpus: 17886
# Collocate words found: 2603
# ['of', 'is', 'crushing', 'something']
# Collocate word: is
# Frequency with parent word: 80
# Frequency in corpus: 142373
# MI score: -2.0111179621699975
# the ocean was salt before we crawled to tears .
# ['the', 'ocean', 'was', 'salt', 'before', 'we', 'crawled', 'to', 'tears', '']
# ocean
# Word of interest: ocean
# Frequncy in corpus: 346
# Collocate words found: 88
# ['the', 'was', 'salt']
# Collocate word: was
# Frequency with parent word: 1
# Frequency in corpus: 131558
# MI score: -2.52715452931587
# each face in the street is a slice of bread
# ['each', 'face', 'in', 'the', 'street', 'is', 'a', 'slice', 'of', 'bread']
# street
# Word of interest: street
# Frequncy in corpus: 3228
# Collocate words found: 378
# ['the', 'is', 'in', 'a']
# Collocate word: is
# Frequency with parent word: 45
# Frequency in corpus: 142373
# MI score: -0.3710746632931407
# my chest was all thunder .
# ['my', 'chest', 'was', 'all', 'thunder', '']
# chest
# Word of interest: chest
# Frequncy in corpus: 394
# Collocate words found: 78
# ['my', 'was', 'all']
# Collocate word: was
# Frequency with parent word: 8
# Frequency in corpus: 131558
# MI score: 0.2854218788644782
# Collocate word: all
# Frequency with parent word: 2
# Frequency in corpus: 38604
# MI score: 0.054298612923791185
# through ivory our dreams are will-o'-the-wisps , scant
# ['through', 'ivory', 'our', 'dreams', 'are', 'willothewisps', '', 'scant']
# dreams
# Word of interest: dreams
# Frequncy in corpus: 357
# Collocate words found: 104
# ['our', 'are', 'ivory', 'willothewisps']
# Collocate word: are
# Frequency with parent word: 14
# Frequency in corpus: 64818
# MI score: 2.256280926149974
# soldiers are citizens of death 's grey land ,
# ['soldiers', 'are', 'citizens', 'of', 'death', 's', 'grey', 'land', '']
# soldiers
# Word of interest: soldiers
# Frequncy in corpus: 760
# Collocate words found: 335
# ['are', 'citizens']
# Collocate word: are
# Frequency with parent word: 12
# Frequency in corpus: 64818
# MI score: 0.9438131605116776
# soldiers are dreamers ; when the guns begin
# ['soldiers', 'are', 'dreamers', '', 'when', 'the', 'guns', 'begin']
# soldiers
# Word of interest: soldiers
# Frequncy in corpus: 760
# Collocate words found: 335
# ['are', 'dreamers']
# Collocate word: are
# Frequency with parent word: 12
# Frequency in corpus: 64818
# MI score: 0.9438131605116776
# the wind was a torrent of darkness among the gusty trees .
# ['the', 'wind', 'was', 'a', 'torrent', 'of', 'darkness', 'among', 'the', 'gusty', 'trees', '']
# wind
# Word of interest: wind
# Frequncy in corpus: 1496
# Collocate words found: 357
# ['the', 'was', 'a']
# Collocate word: was
# Frequency with parent word: 50
# Frequency in corpus: 131558
# MI score: 1.0044354282079424
# the road was a ribbon of moonlight over the purple moor ,
# ['the', 'road', 'was', 'a', 'ribbon', 'of', 'moonlight', 'over', 'the', 'purple', 'moor', '']
# road
# Word of interest: road
# Frequncy in corpus: 3902
# Collocate words found: 462
# ['the', 'was', 'a']
# Collocate word: was
# Frequency with parent word: 47
# Frequency in corpus: 131558
# MI score: -0.46793551261053445
# his eyes were hollows of madness , his hair like mouldy hay ,
# ['his', 'eyes', 'were', 'hollows', 'of', 'madness', '', 'his', 'hair', 'like', 'mouldy', 'hay', '']
# eyes
# Word of interest: eyes
# Frequncy in corpus: 3153
# Collocate words found: 673
# ['his', 'were', 'hollows']
# Collocate word: were
# Frequency with parent word: 145
# Frequency in corpus: 45600
# MI score: 2.9934665851461957
# when the road was a gypsy 's ribbon , looping the purple moor ,
# ['when', 'the', 'road', 'was', 'a', 'gypsy', 's', 'ribbon', '', 'looping', 'the', 'purple', 'moor', '']
# road
# Word of interest: road
# Frequncy in corpus: 3902
# Collocate words found: 462
# ['the', 'was', 'when', 'a']
# Collocate word: was
# Frequency with parent word: 47
# Frequency in corpus: 131558
# MI score: -0.46793551261053445
# Collocate word: when
# Frequency with parent word: 2
# Frequency in corpus: 30789
# MI score: -2.9273122990651763
# when the road is a ribbon of moonlight over the purple moor ,
# ['when', 'the', 'road', 'is', 'a', 'ribbon', 'of', 'moonlight', 'over', 'the', 'purple', 'moor', '']
# road
# Word of interest: road
# Frequncy in corpus: 3902
# Collocate words found: 462
# ['the', 'is', 'when', 'a']
# Collocate word: is
# Frequency with parent word: 45
# Frequency in corpus: 142373
# MI score: -0.6446478626243868
# Collocate word: when
# Frequency with parent word: 2
# Frequency in corpus: 30789
# MI score: -2.9273122990651763
# the watchman 's upper slopes were shadows , green
# ['the', 'watchman', 's', 'upper', 'slopes', 'were', 'shadows', '', 'green']
# slopes
# Word of interest: slopes
# Frequncy in corpus: 219
# Collocate words found: 99
# ['upper', 'were', 's', 'shadows']
# Collocate word: upper
# Frequency with parent word: 11
# Frequency in corpus: 778
# MI score: 8.993831367803994
# Collocate word: were
# Frequency with parent word: 1
# Frequency in corpus: 45600
# MI score: -0.33872010978657774
# -- your mind is water through an april night ,
# ['', 'your', 'mind', 'is', 'water', 'through', 'an', 'april', 'night', '']
# mind
# Word of interest: mind
# Frequncy in corpus: 3840
# Collocate words found: 502
# ['your', 'is', '', 'water']
# Collocate word: is
# Frequency with parent word: 83
# Frequency in corpus: 142373
# MI score: 0.261645939393371
# whose hideous laughter is a bellows mirth
# ['whose', 'hideous', 'laughter', 'is', 'a', 'bellows', 'mirth']
# laughter
# Word of interest: laughter
# Frequncy in corpus: 331
# Collocate words found: 119
# ['hideous', 'is', 'whose', 'a']
# Collocate word: is
# Frequency with parent word: 6
# Frequency in corpus: 142373
# MI score: 0.007772197568903247
# as though a god were issue of the strings . . . .
# ['as', 'though', 'a', 'god', 'were', 'issue', 'of', 'the', 'strings', '', '', '', '']
# god
# Word of interest: god
# Frequncy in corpus: 4442
# Collocate words found: 621
# ['a', 'were', 'though', 'issue']
# Collocate word: were
# Frequency with parent word: 9
# Frequency in corpus: 45600
# MI score: -1.5110017262900726
# whose fell unshadow is death 's utter wound , --
# ['whose', 'fell', 'unshadow', 'is', 'death', 's', 'utter', 'wound', '', '']
# unshadow
# Word of interest: unshadow
# Frequncy in corpus: 0
# Collocate words found: 0
# ['fell', 'is', 'whose', 'death']
# we are driving slowly , the road is glass .
# ['we', 'are', 'driving', 'slowly', '', 'the', 'road', 'is', 'glass', '']
# road
# Word of interest: road
# Frequncy in corpus: 3902
# Collocate words found: 462
# ['the', 'is', '', 'glass']
# Collocate word: is
# Frequency with parent word: 45
# Frequency in corpus: 142373
# MI score: -0.6446478626243868
# even memory is a stranger .
# ['even', 'memory', 'is', 'a', 'stranger', '']
# memory
# Word of interest: memory
# Frequncy in corpus: 885
# Collocate words found: 196
# ['even', 'is', 'a']
# Collocate word: even
# Frequency with parent word: 1
# Frequency in corpus: 14822
# MI score: -0.7321730009603445
# Collocate word: is
# Frequency with parent word: 24
# Frequency in corpus: 142373
# MI score: 0.5889259594057612
# `the countess cathleen' was the name i gave it ,
# ['the', 'countess', 'cathleen', 'was', 'the', 'name', 'i', 'gave', 'it', '']
# cathleen
# Word of interest: cathleen
# Frequncy in corpus: 0
# Collocate words found: 0
# ['countess', 'was', 'the', 'the']
# the laugh was a cry from my own
# ['the', 'laugh', 'was', 'a', 'cry', 'from', 'my', 'own']
# laugh
# Word of interest: laugh
# Frequncy in corpus: 406
# Collocate words found: 115
# ['the', 'was', 'a']
# Collocate word: was
# Frequency with parent word: 3
# Frequency in corpus: 131558
# MI score: -1.1728997181431655
# in the field is a house
# ['in', 'the', 'field', 'is', 'a', 'house']
# field
# Word of interest: field
# Frequncy in corpus: 1946
# Collocate words found: 410
# ['the', 'is', 'in', 'a']
# Collocate word: is
# Frequency with parent word: 44
# Frequency in corpus: 142373
# MI score: 0.3266327275111504
# hope is command . your hand
# ['hope', 'is', 'command', '', 'your', 'hand']
# hope
# Word of interest: hope
# Frequncy in corpus: 2252
# Collocate words found: 225
# ['is', 'command']
# Collocate word: is
# Frequency with parent word: 52
# Frequency in corpus: 142373
# MI score: 0.3569457097158274
# their country is a nation on no map .
# ['their', 'country', 'is', 'a', 'nation', 'on', 'no', 'map', '']
# country
# Word of interest: country
# Frequncy in corpus: 5496
# Collocate words found: 651
# ['their', 'is', 'a']
# Collocate word: is
# Frequency with parent word: 102
# Frequency in corpus: 142373
# MI score: 0.04175615680836037
# blacktime is time for chimeful
# ['blacktime', 'is', 'time', 'for', 'chimeful']
# blacktime
# Word of interest: blacktime
# Frequncy in corpus: 0
# Collocate words found: 0
# ['is', 'time']
# shaving lotion , as if the stuff were scotch ,
# ['shaving', 'lotion', '', 'as', 'if', 'the', 'stuff', 'were', 'scotch', '']
# stuff
# Word of interest: stuff
# Frequncy in corpus: 686
# Collocate words found: 252
# ['the', 'were', 'if', 'scotch']
# our effort to remake the found world as the lost reverie is desire .
# ['our', 'effort', 'to', 'remake', 'the', 'found', 'world', 'as', 'the', 'lost', 'reverie', 'is', 'desire', '']
# reverie
# Word of interest: reverie
# Frequncy in corpus: 15
# Collocate words found: 6
# ['lost', 'is', 'the', 'desire']
# his literature is lives , is deif smiling :
# ['his', 'literature', 'is', 'lives', '', 'is', 'deif', 'smiling', '']
# literature
# Word of interest: literature
# Frequncy in corpus: 854
# Collocate words found: 242
# ['his', 'is', 'lives']
# Collocate word: is
# Frequency with parent word: 25
# Frequency in corpus: 142373
# MI score: 0.699261033809199
# he speaks : his fiat is a fiat ,
# ['he', 'speaks', '', 'his', 'fiat', 'is', 'a', 'fiat', '']
# fiat
# Word of interest: fiat
# Frequncy in corpus: 58
# Collocate words found: 16
# ['his', 'is', '', 'a']
# Collocate word: is
# Frequency with parent word: 1
# Frequency in corpus: 142373
# MI score: -0.06448389147260727
# whitman 's father was a carpenter .
# ['whitman', 's', 'father', 'was', 'a', 'carpenter', '']
# father
# Word of interest: father
# Frequncy in corpus: 3588
# Collocate words found: 525
# ['s', 'was', 'whitman', 'a']
# Collocate word: was
# Frequency with parent word: 230
# Frequency in corpus: 131558
# MI score: 1.9439995743459684
# that all workmen are singers .
# ['that', 'all', 'workmen', 'are', 'singers', '']
# workmen
# Word of interest: workmen
# Frequncy in corpus: 72
# Collocate words found: 48
# ['all', 'are', 'that', 'singers']
# Collocate word: are
# Frequency with parent word: 1
# Frequency in corpus: 64818
# MI score: 0.7587812666791568
# to other laws : "weight is the measure of
# ['to', 'other', 'laws', '', 'weight', 'is', 'the', 'measure', 'of']
# weight
# Word of interest: weight
# Frequncy in corpus: 1500
# Collocate words found: 316
# ['', 'is', 'laws', 'the']
# Collocate word: is
# Frequency with parent word: 44
# Frequency in corpus: 142373
# MI score: 0.7021819369090189
# unclean is the nature and name of the enchantment .
# ['unclean', 'is', 'the', 'nature', 'and', 'name', 'of', 'the', 'enchantment', '']
# unclean
# Word of interest: unclean
# Frequncy in corpus: 53
# Collocate words found: 16
# ['is', 'the']
# Collocate word: is
# Frequency with parent word: 3
# Frequency in corpus: 142373
# MI score: 1.6505391498129218
# going to bed was a journey .
# ['going', 'to', 'bed', 'was', 'a', 'journey', '']
# bed
# Word of interest: bed
# Frequncy in corpus: 2006
# Collocate words found: 243
# ['to', 'was', 'going', 'a']
# Collocate word: was
# Frequency with parent word: 24
# Frequency in corpus: 131558
# MI score: -0.4776696915701699
# the fateful masks are faces , gods are men ;
# ['the', 'fateful', 'masks', 'are', 'faces', '', 'gods', 'are', 'men', '']
# masks
# Word of interest: masks
# Frequncy in corpus: 77
# Collocate words found: 41
# ['fateful', 'are', 'the', 'faces']
# the fateful masks are faces , gods are men ;
# ['the', 'fateful', 'masks', 'are', 'faces', '', 'gods', 'are', 'men', '']
# gods
# Word of interest: gods
# Frequncy in corpus: 307
# Collocate words found: 102
# ['', 'are', 'faces', 'men']
# Collocate word: are
# Frequency with parent word: 14
# Frequency in corpus: 64818
# MI score: 2.4739663448088938
# the telephone is flaubert 's parrot and it flitters
# ['the', 'telephone', 'is', 'flaubert', 's', 'parrot', 'and', 'it', 'flitters']
# telephone
# Word of interest: telephone
# Frequncy in corpus: 1020
# Collocate words found: 228
# ['the', 'is', 'flaubert']
# Collocate word: is
# Frequency with parent word: 3
# Frequency in corpus: 142373
# MI score: -2.6158938324827368
# of her . the telephone is the guignol of
# ['of', 'her', '', 'the', 'telephone', 'is', 'the', 'guignol', 'of']
# telephone
# Word of interest: telephone
# Frequncy in corpus: 1020
# Collocate words found: 228
# ['the', 'is', '', 'the']
# Collocate word: is
# Frequency with parent word: 3
# Frequency in corpus: 142373
# MI score: -2.6158938324827368
# city of rock and ice , that men are freaks ,
# ['city', 'of', 'rock', 'and', 'ice', '', 'that', 'men', 'are', 'freaks', '']
# men
# Word of interest: men
# Frequncy in corpus: 5778
# Collocate words found: 1364
# ['that', 'are', '', 'freaks']
# Collocate word: are
# Frequency with parent word: 169
# Frequency in corpus: 64818
# MI score: 1.833231215839038
# it is not you i love ?it is the form
# ['it', 'is', 'not', 'you', 'i', 'love', 'it', 'is', 'the', 'form']
# it
# Word of interest: it
# Frequncy in corpus: 131450
# Collocate words found: 6930
# ['love', 'is', 'i', 'the']
# Collocate word: love
# Frequency with parent word: 57
# Frequency in corpus: 3233
# MI score: 0.08289075939994779
# Collocate word: is
# Frequency with parent word: 23066
# Frequency in corpus: 142373
# MI score: 3.2828227069614617
# Collocate word: i
# Frequency with parent word: 1
# Frequency in corpus: 85678
# MI score: -10.477978645528443
# the thought of death is peppermint to you
# ['the', 'thought', 'of', 'death', 'is', 'peppermint', 'to', 'you']
# death
# Word of interest: death
# Frequncy in corpus: 3336
# Collocate words found: 402
# ['of', 'is', 'thought', 'peppermint']
# Collocate word: is
# Frequency with parent word: 86
# Frequency in corpus: 142373
# MI score: 0.5158582849123992
# scarce fresher is the mountain-sod
# ['scarce', 'fresher', 'is', 'the', 'mountainsod']
# fresher
# Word of interest: fresher
# Frequncy in corpus: 19
# Collocate words found: 4
# ['scarce', 'is', 'the']
# but , ah ! its heart , its heart was stone ,
# ['but', '', 'ah', '', 'its', 'heart', '', 'its', 'heart', 'was', 'stone', '']
# heart
# Word of interest: heart
# Frequncy in corpus: 2116
# Collocate words found: 340
# ['its', 'was', '', 'stone']
# Collocate word: was
# Frequency with parent word: 42
# Frequency in corpus: 131558
# MI score: 0.25266720898558903
# but for peace her soul was yearning ,
# ['but', 'for', 'peace', 'her', 'soul', 'was', 'yearning', '']
# soul
# Word of interest: soul
# Frequncy in corpus: 685
# Collocate words found: 162
# ['her', 'was', 'peace', 'yearning']
# Collocate word: was
# Frequency with parent word: 10
# Frequency in corpus: 131558
# MI score: -0.19055838463967228
# Collocate word: yearning
# Frequency with parent word: 1
# Frequency in corpus: 71
# MI score: 7.343105856401491
# "o sohrab , an unquiet heart is thine !
# ['o', 'sohrab', '', 'an', 'unquiet', 'heart', 'is', 'thine', '']
# heart
# Word of interest: heart
# Frequncy in corpus: 2116
# Collocate words found: 340
# ['unquiet', 'is', 'an', 'thine']
# Collocate word: is
# Frequency with parent word: 50
# Frequency in corpus: 142373
# MI score: 0.39022938131566365
# whose culture is the brethren 's care ;
# ['whose', 'culture', 'is', 'the', 'brethren', 's', 'care', '']
# culture
# Word of interest: culture
# Frequncy in corpus: 1482
# Collocate words found: 369
# ['whose', 'is', 'the']
# Collocate word: is
# Frequency with parent word: 54
# Frequency in corpus: 142373
# MI score: 1.0150548735125995
# and what sedged brooks are thames 's tributaries ;
# ['and', 'what', 'sedged', 'brooks', 'are', 'thames', 's', 'tributaries', '']
# brooks
# Word of interest: brooks
# Frequncy in corpus: 58
# Collocate words found: 19
# ['sedged', 'are', 'what', 'thames']
# thy rights are empire : urge no meaner claim , --
# ['thy', 'rights', 'are', 'empire', '', 'urge', 'no', 'meaner', 'claim', '', '']
# rights
# Word of interest: rights
# Frequncy in corpus: 1942
# Collocate words found: 305
# ['thy', 'are', 'empire']
# Collocate word: are
# Frequency with parent word: 32
# Frequency in corpus: 64818
# MI score: 1.0053787827022769
# answer 'd the lovely maid and said : "i am a watry weed ,
# ['answer', 'd', 'the', 'lovely', 'maid', 'and', 'said', '', 'i', 'am', 'a', 'watry', 'weed', '']
# i
# Word of interest: i
# Frequncy in corpus: 85672
# Collocate words found: 3061
# ['', 'am', 'said', 'a']
# Collocate word: am
# Frequency with parent word: 3609
# Frequency in corpus: 3957
# MI score: 6.393469083749452
# Collocate word: said
# Frequency with parent word: 1273
# Frequency in corpus: 26624
# MI score: 2.139853991585187
# and their ways are fill 'd with thorns .
# ['and', 'their', 'ways', 'are', 'fill', 'd', 'with', 'thorns', '']
# ways
# Word of interest: ways
# Frequncy in corpus: 2175
# Collocate words found: 447
# ['their', 'are', 'and', 'fill']
# Collocate word: are
# Frequency with parent word: 23
# Frequency in corpus: 64818
# MI score: 0.36546853855502914
# his breast is love 's all worship 'd tomb ,
# ['his', 'breast', 'is', 'love', 's', 'all', 'worship', 'd', 'tomb', '']
# breast
# Word of interest: breast
# Frequncy in corpus: 230
# Collocate words found: 64
# ['his', 'is', 'love']
# Collocate word: is
# Frequency with parent word: 2
# Frequency in corpus: 142373
# MI score: -1.0519929472894103
# " no peace be thine , " exclaimed , "away , away ! "
# ['', 'no', 'peace', 'be', 'thine', '', '', 'exclaimed', '', 'away', '', 'away', '', '']
# peace
# Word of interest: peace
# Frequncy in corpus: 1431
# Collocate words found: 281
# ['no', 'be', '', 'thine']
# Collocate word: no
# Frequency with parent word: 2
# Frequency in corpus: 26841
# MI score: -1.2821456047369666
# Collocate word: be
# Frequency with parent word: 4
# Frequency in corpus: 87685
# MI score: -1.9900372489493279
# inventing one . in brief , all arts are mine ;
# ['inventing', 'one', '', 'in', 'brief', '', 'all', 'arts', 'are', 'mine', '']
# arts
# Word of interest: arts
# Frequncy in corpus: 887
# Collocate words found: 145
# ['all', 'are', '', 'mine']
# Collocate word: all
# Frequency with parent word: 2
# Frequency in corpus: 38604
# MI score: -1.1164398619208964
# Collocate word: are
# Frequency with parent word: 7
# Frequency in corpus: 64818
# MI score: -0.056729104121990635
# outside was all noon and the burning blue .
# ['outside', 'was', 'all', 'noon', 'and', 'the', 'burning', 'blue', '']
# outside
# Word of interest: outside
# Frequncy in corpus: 3137
# Collocate words found: 523
# ['was', 'all']
# Collocate word: was
# Frequency with parent word: 38
# Frequency in corpus: 131558
# MI score: -0.4597686020791628
# Collocate word: all
# Frequency with parent word: 5
# Frequency in corpus: 38604
# MI score: -1.6168912865760732
# "i am the resurrection and the life . "
# ['i', 'am', 'the', 'resurrection', 'and', 'the', 'life', '', '']
# i
# Word of interest: i
# Frequncy in corpus: 85672
# Collocate words found: 3061
# ['am', 'the']
# Collocate word: am
# Frequency with parent word: 3609
# Frequency in corpus: 3957
# MI score: 6.393469083749452
# take away love , and our earth is a tomb !
# ['take', 'away', 'love', '', 'and', 'our', 'earth', 'is', 'a', 'tomb', '']
# earth
# Word of interest: earth
# Frequncy in corpus: 1360
# Collocate words found: 236
# ['our', 'is', 'and', 'a']
# Collocate word: is
# Frequency with parent word: 38
# Frequency in corpus: 142373
# MI score: 0.6320336809608486
# first , every sort of monk , the black and whitethe black and the white black friars are dominicans ; white friars are carmelites ,
# ['first', '', 'every', 'sort', 'of', 'monk', '', 'the', 'black', 'and', 'whitethe', 'black', 'and', 'the', 'white', 'black', 'friars', 'are', 'dominicans', '', 'white', 'friars', 'are', 'carmelites', '']
# friars
# Word of interest: friars
# Frequncy in corpus: 14
# Collocate words found: 9
# ['black', 'are', 'white', 'dominicans']
# Collocate word: black
# Frequency with parent word: 2
# Frequency in corpus: 3675
# MI score: 8.26192969708537
# first , every sort of monk , the black and whitethe black and the white black friars are dominicans ; white friars are carmelites ,
# ['first', '', 'every', 'sort', 'of', 'monk', '', 'the', 'black', 'and', 'whitethe', 'black', 'and', 'the', 'white', 'black', 'friars', 'are', 'dominicans', '', 'white', 'friars', 'are', 'carmelites', '']
# friars
# Word of interest: friars
# Frequncy in corpus: 14
# Collocate words found: 9
# ['white', 'are', '', 'carmelites']
# his name is guidi -- he 'll not mind the monks --
# ['his', 'name', 'is', 'guidi', '', 'he', 'll', 'not', 'mind', 'the', 'monks', '']
# name
# Word of interest: name
# Frequncy in corpus: 3448
# Collocate words found: 410
# ['his', 'is', 'guidi']
# Collocate word: is
# Frequency with parent word: 143
# Frequency in corpus: 142373
# MI score: 1.201824381344256
# no! yonder sparkle is the citadel 's
# ['no', 'yonder', 'sparkle', 'is', 'the', 'citadel', 's']
# sparkle
# Word of interest: sparkle
# Frequncy in corpus: 40
# Collocate words found: 22
# ['yonder', 'is', 'no', 'the']
# our low life was the level 's and the night 's ;
# ['our', 'low', 'life', 'was', 'the', 'level', 's', 'and', 'the', 'night', 's', '']
# life
# Word of interest: life
# Frequncy in corpus: 9588
# Collocate words found: 1149
# ['low', 'was', 'our', 'the']
# Collocate word: low
# Frequency with parent word: 3
# Frequency in corpus: 2404
# MI score: 0.039540280114899795
# Collocate word: was
# Frequency with parent word: 215
# Frequency in corpus: 131558
# MI score: 0.4286523542611818
# what matter to me if their star is a world ?
# ['what', 'matter', 'to', 'me', 'if', 'their', 'star', 'is', 'a', 'world', '']
# star
# Word of interest: star
# Frequncy in corpus: 989
# Collocate words found: 240
# ['their', 'is', 'if', 'a']
# Collocate word: is
# Frequency with parent word: 14
# Frequency in corpus: 142373
# MI score: -0.3489746850465419
# and with god be the rest !
# ['and', 'with', 'god', 'be', 'the', 'rest', '']
# god
# Word of interest: god
# Frequncy in corpus: 4442
# Collocate words found: 621
# ['with', 'be', 'and', 'the']
# Collocate word: be
# Frequency with parent word: 24
# Frequency in corpus: 87685
# ...
# past
# Word of interest: past
# Frequncy in corpus: 3992
# Collocate words found: 676
# ['the', 'is', '', 'the']
# Collocate word: is
# Frequency with parent word: 53
# Frequency in corpus: 142373
# MI score: -0.4414784471190965
# his back is a saddle where lovers have ridden .
# ['his', 'back', 'is', 'a', 'saddle', 'where', 'lovers', 'have', 'ridden', '']
# back
# Word of interest: back
# Frequncy in corpus: 13257
# Collocate words found: 1461
# ['his', 'is', 'a']
# Collocate word: is
# Frequency with parent word: 90
# Frequency in corpus: 142373
# MI score: -1.409116516493522
# the horizon h is the point where vision ends
# ['the', 'horizon', 'h', 'is', 'the', 'point', 'where', 'vision', 'ends']
# h
# Word of interest: h
# Frequncy in corpus: 224
# Collocate words found: 33
# ['horizon', 'is', 'the', 'the']
# Collocate word: is
# Frequency with parent word: 7
# Frequency in corpus: 142373
# MI score: 0.7934971036549647
# where people were days becoming months and years .
# ['where', 'people', 'were', 'days', 'becoming', 'months', 'and', 'years', '']
# people
# Word of interest: people
# Frequncy in corpus: 17886
# Collocate words found: 2603
# ['where', 'were', 'days']
# Collocate word: where
# Frequency with parent word: 67
# Frequency in corpus: 14021
# MI score: 1.077057555629198
# Collocate word: were
# Frequency with parent word: 509
# Frequency in corpus: 45600
# MI score: 2.301045635177966
# the wind of my breath is a hurricane :
# ['the', 'wind', 'of', 'my', 'breath', 'is', 'a', 'hurricane', '']
# breath
# Word of interest: breath
# Frequncy in corpus: 518
# Collocate words found: 112
# ['my', 'is', 'of', 'a']
# Collocate word: is
# Frequency with parent word: 2
# Frequency in corpus: 142373
# MI score: -2.223311184031589
# but the word is mindful of itself
# ['but', 'the', 'word', 'is', 'mindful', 'of', 'itself']
# word
# Word of interest: word
# Frequncy in corpus: 2134
# Collocate words found: 348
# ['the', 'is', 'but', 'mindful']
# Collocate word: is
# Frequency with parent word: 53
# Frequency in corpus: 142373
# MI score: 0.46207309739373903
# they say a ghost is a ghost
# ['they', 'say', 'a', 'ghost', 'is', 'a', 'ghost']
# ghost
# Word of interest: ghost
# Frequncy in corpus: 177
# Collocate words found: 38
# ['a', 'is', 'say', 'a']
# Collocate word: is
# Frequency with parent word: 2
# Frequency in corpus: 142373
# MI score: -0.6741084464280326
# yes , the sun at its zenith , winged figure with arms extended , and a white ship , exactly correct . let me tell you what it is you said . the lovers ' limbs twist like a river . their talk is a naming or being named . my back sometimes aches . their talk hides in the telling . the wind moves us . wands comes and cups , gardens , someone in a cloak , the wind moves us , laws , young girl and the bird at her wrist , colors , bright yellow or blue . i am a woman or man under green sky , garden to my right and then it 's the following day . i am woman or man under emerald sky , wind brushes the river 's surface , we talk until our talk becomes hidden .
# ['yes', '', 'the', 'sun', 'at', 'its', 'zenith', '', 'winged', 'figure', 'with', 'arms', 'extended', '', 'and', 'a', 'white', 'ship', '', 'exactly', 'correct', '', 'let', 'me', 'tell', 'you', 'what', 'it', 'is', 'you', 'said', '', 'the', 'lovers', '', 'limbs', 'twist', 'like', 'a', 'river', '', 'their', 'talk', 'is', 'a', 'naming', 'or', 'being', 'named', '', 'my', 'back', 'sometimes', 'aches', '', 'their', 'talk', 'hides', 'in', 'the', 'telling', '', 'the', 'wind', 'moves', 'us', '', 'wands', 'comes', 'and', 'cups', '', 'gardens', '', 'someone', 'in', 'a', 'cloak', '', 'the', 'wind', 'moves', 'us', '', 'laws', '', 'young', 'girl', 'and', 'the', 'bird', 'at', 'her', 'wrist', '', 'colors', '', 'bright', 'yellow', 'or', 'blue', '', 'i', 'am', 'a', 'woman', 'or', 'man', 'under', 'green', 'sky', '', 'garden', 'to', 'my', 'right', 'and', 'then', 'it', 's', 'the', 'following', 'day', '', 'i', 'am', 'woman', 'or', 'man', 'under', 'emerald', 'sky', '', 'wind', 'brushes', 'the', 'river', 's', 'surface', '', 'we', 'talk', 'until', 'our', 'talk', 'becomes', 'hidden', '']
# talk
# Word of interest: talk
# Frequncy in corpus: 2104
# Collocate words found: 281
# ['their', 'is', '', 'a']
# Collocate word: is
# Frequency with parent word: 37
# Frequency in corpus: 142373
# MI score: -0.035968520008387794
# talk is a naming .
# ['talk', 'is', 'a', 'naming', '']
# talk
# Word of interest: talk
# Frequncy in corpus: 2104
# Collocate words found: 281
# ['is', 'a']
# Collocate word: is
# Frequency with parent word: 37
# Frequency in corpus: 142373
# MI score: -0.035968520008387794
# talk is a naming or a being named . . .
# ['talk', 'is', 'a', 'naming', 'or', 'a', 'being', 'named', '', '', '']
# talk
# Word of interest: talk
# Frequncy in corpus: 2104
# Collocate words found: 281
# ['is', 'a']
# Collocate word: is
# Frequency with parent word: 37
# Frequency in corpus: 142373
# MI score: -0.035968520008387794
# whose doldrums are meadows spinning into brush ,
# ['whose', 'doldrums', 'are', 'meadows', 'spinning', 'into', 'brush', '']
# doldrums
# Word of interest: doldrums
# Frequncy in corpus: 20
# Collocate words found: 4
# ['whose', 'are', 'meadows']
# her name was sara and we kept it at that .
# ['her', 'name', 'was', 'sara', 'and', 'we', 'kept', 'it', 'at', 'that', '']
# name
# Word of interest: name
# Frequncy in corpus: 3448
# Collocate words found: 410
# ['her', 'was', 'sara']
# Collocate word: was
# Frequency with parent word: 161
# Frequency in corpus: 131558
# MI score: 1.4868465173463734
# the soul is forgiveness because it knows forgiveness .
# ['the', 'soul', 'is', 'forgiveness', 'because', 'it', 'knows', 'forgiveness', '']
# soul
# Word of interest: soul
# Frequncy in corpus: 685
# Collocate words found: 162
# ['the', 'is', 'forgiveness']
# Collocate word: is
# Frequency with parent word: 16
# Frequency in corpus: 142373
# MI score: 0.3735369258070757
# and his screen is stripes and he knows he saved his work
# ['and', 'his', 'screen', 'is', 'stripes', 'and', 'he', 'knows', 'he', 'saved', 'his', 'work']
# screen
# Word of interest: screen
# Frequncy in corpus: 694
# Collocate words found: 163
# ['his', 'is', 'and', 'stripes']
# Collocate word: is
# Frequency with parent word: 12
# Frequency in corpus: 142373
# MI score: -0.06033224820213996
# god was momentum then ,
# ['god', 'was', 'momentum', 'then', '']
# god
# Word of interest: god
# Frequncy in corpus: 4442
# Collocate words found: 621
# ['was', 'momentum']
# Collocate word: was
# Frequency with parent word: 84
# Frequency in corpus: 131558
# MI score: 0.18279744355263416
# that looks personal , private . this tank is nothing
# ['that', 'looks', 'personal', '', 'private', '', 'this', 'tank', 'is', 'nothing']
# tank
# Word of interest: tank
# Frequncy in corpus: 349
# Collocate words found: 99
# ['this', 'is', '', 'nothing']
# Collocate word: this
# Frequency with parent word: 1
# Frequency in corpus: 60183
# MI score: -1.4113384758788112
# Collocate word: is
# Frequency with parent word: 11
# Frequency in corpus: 142373
# MI score: 0.8058454960826098
# what is the world ? the word is wilderness .
# ['what', 'is', 'the', 'world', '', 'the', 'word', 'is', 'wilderness', '']
# word
# Word of interest: word
# Frequncy in corpus: 2134
# Collocate words found: 348
# ['the', 'is', '', 'wilderness']
# Collocate word: is
# Frequency with parent word: 53
# Frequency in corpus: 142373
# MI score: 0.46207309739373903
# what is the answer ? the answer is the world .
# ['what', 'is', 'the', 'answer', '', 'the', 'answer', 'is', 'the', 'world', '']
# answer
# Word of interest: answer
# Frequncy in corpus: 1635
# Collocate words found: 225
# ['the', 'is', '', 'the']
# Collocate word: is
# Frequency with parent word: 173
# Frequency in corpus: 142373
# MI score: 2.5530504109062444
# what is the beginning ? a beginning is happiness .
# ['what', 'is', 'the', 'beginning', '', 'a', 'beginning', 'is', 'happiness', '']
# beginning
# Word of interest: beginning
# Frequncy in corpus: 1799
# Collocate words found: 108
# ['a', 'is', '', 'happiness']
# Collocate word: is
# Frequency with parent word: 66
# Frequency in corpus: 142373
# MI score: 1.024911751761936
# paul was the sort
# ['paul', 'was', 'the', 'sort']
# paul
# Word of interest: paul
# Frequncy in corpus: 1494
# Collocate words found: 211
# ['was', 'the']
# Collocate word: was
# Frequency with parent word: 38
# Frequency in corpus: 131558
# MI score: 0.6104367789752028
# a father tells his son the thing he regrets most about his life is the amount of time he has spent worrying about it .
# ['a', 'father', 'tells', 'his', 'son', 'the', 'thing', 'he', 'regrets', 'most', 'about', 'his', 'life', 'is', 'the', 'amount', 'of', 'time', 'he', 'has', 'spent', 'worrying', 'about', 'it', '']
# life
# Word of interest: life
# Frequncy in corpus: 9588
# Collocate words found: 1149
# ['his', 'is', 'about', 'the']
# Collocate word: is
# Frequency with parent word: 346
# Frequency in corpus: 142373
# MI score: 1.0011111376425565
# those people were a kind of solution .
# ['those', 'people', 'were', 'a', 'kind', 'of', 'solution', '']
# people
# Word of interest: people
# Frequncy in corpus: 17886
# Collocate words found: 2603
# ['those', 'were', 'a']
# Collocate word: those
# Frequency with parent word: 105
# Frequency in corpus: 12061
# MI score: 1.9424536024253072
# Collocate word: were
# Frequency with parent word: 509
# Frequency in corpus: 45600
# MI score: 2.301045635177966
# "in the star " "it is a star " "it is autonomous " " star & it 's mild " "is
# ['in', 'the', 'star', '', 'it', 'is', 'a', 'star', '', 'it', 'is', 'autonomous', '', '', 'star', '', 'it', 's', 'mild', '', 'is']
# it
# Word of interest: it
# Frequncy in corpus: 131450
# Collocate words found: 6930
# ['', 'is', 'star', 'a']
# Collocate word: is
# Frequency with parent word: 23066
# Frequency in corpus: 142373
# MI score: 3.2828227069614617
# my father 's farm is an apple blossomer .
# ['my', 'father', 's', 'farm', 'is', 'an', 'apple', 'blossomer', '']
# farm
# Word of interest: farm
# Frequncy in corpus: 1447
# Collocate words found: 237
# ['s', 'is', 'father', 'an']
# Collocate word: is
# Frequency with parent word: 12
# Frequency in corpus: 142373
# MI score: -1.1203896021556035
# his fields are oceans of heat ,
# ['his', 'fields', 'are', 'oceans', 'of', 'heat', '']
# fields
# Word of interest: fields
# Frequncy in corpus: 806
# Collocate words found: 238
# ['his', 'are', 'oceans']
# Collocate word: are
# Frequency with parent word: 22
# Frequency in corpus: 64818
# MI score: 1.7335018582307993
# my father 's farm is an icicle ,
# ['my', 'father', 's', 'farm', 'is', 'an', 'icicle', '']
# farm
# Word of interest: farm
# Frequncy in corpus: 1447
# Collocate words found: 237
# ['s', 'is', 'father', 'an']
# Collocate word: is
# Frequency with parent word: 12
# Frequency in corpus: 142373
# MI score: -1.1203896021556035
# today is friday .
# ['today', 'is', 'friday', '']
# today
# Word of interest: today
# Frequncy in corpus: 3654
# Collocate words found: 633
# ['is', 'friday']
# Collocate word: is
# Frequency with parent word: 155
# Frequency in corpus: 142373
# MI score: 1.2343605903017139
# his left leg was meal . crayfish in the hair .
# ['his', 'left', 'leg', 'was', 'meal', '', 'crayfish', 'in', 'the', 'hair', '']
# leg
# Word of interest: leg
# Frequncy in corpus: 921
# Collocate words found: 236
# ['left', 'was', 'his', 'meal']
# Collocate word: left
# Frequency with parent word: 27
# Frequency in corpus: 7000
# MI score: 5.047504103106504
# Collocate word: was
# Frequency with parent word: 21
# Frequency in corpus: 131558
# MI score: 0.45273377500827905
# the risk is a part of the rhythm
# ['the', 'risk', 'is', 'a', 'part', 'of', 'the', 'rhythm']
# risk
# Word of interest: risk
# Frequncy in corpus: 1510
# Collocate words found: 251
# ['the', 'is', 'a']
# Collocate word: is
# Frequency with parent word: 34
# Frequency in corpus: 142373
# MI score: 0.3206271106928629
# mentions that hearing is silver
# ['mentions', 'that', 'hearing', 'is', 'silver']
# hearing
# Word of interest: hearing
# Frequncy in corpus: 580
# Collocate words found: 125
# ['that', 'is', 'mentions', 'silver']
# Collocate word: that
# Frequency with parent word: 4
# Frequency in corpus: 139498
# MI score: -1.3569808488040054
# Collocate word: is
# Frequency with parent word: 9
# Frequency in corpus: 142373
# MI score: -0.21648698491765722
# the name is orestes
# ['the', 'name', 'is', 'orestes']
# name
# Word of interest: name
# Frequncy in corpus: 3448
# Collocate words found: 410
# ['the', 'is', 'orestes']
# Collocate word: is
# Frequency with parent word: 143
# Frequency in corpus: 142373
# MI score: 1.201824381344256
# no one can escape , what use is strength , you ca n't
# ['no', 'one', 'can', 'escape', '', 'what', 'use', 'is', 'strength', '', 'you', 'ca', 'nt']
# use
# Word of interest: use
# Frequncy in corpus: 7361
# Collocate words found: 821
# ['what', 'is', '', 'strength']
# Collocate word: is
# Frequency with parent word: 61
# Frequency in corpus: 142373
# MI score: -1.121451614759213
# and behind was memory like the white sheet one night in an enclosure
# ['and', 'behind', 'was', 'memory', 'like', 'the', 'white', 'sheet', 'one', 'night', 'in', 'an', 'enclosure']
# behind
# Word of interest: behind
# Frequncy in corpus: 3702
# Collocate words found: 610
# ['and', 'was', 'memory']
# Collocate word: was
# Frequency with parent word: 39
# Frequency in corpus: 131558
# MI score: -0.6612132626874713
# the perfume was flowers ground upon stones .
# ['the', 'perfume', 'was', 'flowers', 'ground', 'upon', 'stones', '']
# perfume
# Word of interest: perfume
# Frequncy in corpus: 78
# Collocate words found: 31
# ['the', 'was', 'flowers']
# Collocate word: was
# Frequency with parent word: 1
# Frequency in corpus: 131558
# MI score: -0.3779285205413939
# to cleanse our vision : the fish were silver ,
# ['to', 'cleanse', 'our', 'vision', '', 'the', 'fish', 'were', 'silver', '']
# fish
# Word of interest: fish
# Frequncy in corpus: 1471
# Collocate words found: 466
# ['the', 'were', '', 'silver']
# Collocate word: were
# Frequency with parent word: 12
# Frequency in corpus: 45600
# MI score: 0.49844791928092175
# martin was a man no one came close to knowing .
# ['martin', 'was', 'a', 'man', 'no', 'one', 'came', 'close', 'to', 'knowing', '']
# martin
# Word of interest: martin
# Frequncy in corpus: 782
# Collocate words found: 117
# ['was', 'a']
# Collocate word: was
# Frequency with parent word: 8
# Frequency in corpus: 131558
# MI score: -0.7035510989864978
# was a joke because " a singer is nothing " --
# ['was', 'a', 'joke', 'because', '', 'a', 'singer', 'is', 'nothing', '', '']
# singer
# Word of interest: singer
# Frequncy in corpus: 281
# Collocate words found: 83
# ['a', 'is', '', 'nothing']
# Collocate word: is
# Frequency with parent word: 5
# Frequency in corpus: 142373
# MI score: -0.01900112167859886
# " a singer is nothing . " why did he sing ?
# ['', 'a', 'singer', 'is', 'nothing', '', '', 'why', 'did', 'he', 'sing', '']
# singer
# Word of interest: singer
# Frequncy in corpus: 281
# Collocate words found: 83
# ['a', 'is', '', 'nothing']
# Collocate word: is
# Frequency with parent word: 5
# Frequency in corpus: 142373
# MI score: -0.01900112167859886
# as the season of cold is the season of darkness
# ['as', 'the', 'season', 'of', 'cold', 'is', 'the', 'season', 'of', 'darkness']
# cold
# Word of interest: cold
# Frequncy in corpus: 1876
# Collocate words found: 286
# ['of', 'is', 'season', 'the']
# Collocate word: is
# Frequency with parent word: 36
# Frequency in corpus: 142373
# MI score: 0.08997799258190067
# else all beasts were tigers ,
# ['else', 'all', 'beasts', 'were', 'tigers', '']
# beasts
# Word of interest: beasts
# Frequncy in corpus: 71
# Collocate words found: 41
# ['all', 'were', 'else', 'tigers']
# without which earth is sand
# ['without', 'which', 'earth', 'is', 'sand']
# earth
# Word of interest: earth
# Frequncy in corpus: 1360
# Collocate words found: 236
# ['which', 'is', 'without', 'sand']
# Collocate word: is
# Frequency with parent word: 38
# Frequency in corpus: 142373
# MI score: 0.6320336809608486
# the sky is cloud on cloud
# ['the', 'sky', 'is', 'cloud', 'on', 'cloud']
# sky
# Word of interest: sky
# Frequncy in corpus: 743
# Collocate words found: 174
# ['the', 'is', 'cloud']
# Collocate word: is
# Frequency with parent word: 23
# Frequency in corpus: 142373
# MI score: 0.7798406591733814
# the sky is cloudy
# ['the', 'sky', 'is', 'cloudy']
# sky
# Word of interest: sky
# Frequncy in corpus: 743
# Collocate words found: 174
# ['the', 'is', 'cloudy']
# Collocate word: is
# Frequency with parent word: 23
# Frequency in corpus: 142373
# MI score: 0.7798406591733814
# Collocate word: cloudy
# Frequency with parent word: 2
# Frequency in corpus: 44
# MI score: 8.916163134578168

# %%
print(len(predictions))
print(len(isSentenceMetaphor))
# Out:
# 680
# 680

# %%
PredictedPositives = predictions.count('y')
PredictedNegatives = predictions.count('n')
TruePositives = 0
FalsePositives = 0
TrueNegatives = 0
FalseNegatives = 0

#Unknown results are skipped
for i in range(len(isSentenceMetaphor)):
    if predictions[i] == 'y' and isSentenceMetaphor[i] == 'y':
        TruePositives +=1
    elif predictions[i] == 'y' and isSentenceMetaphor[i] == 'n':
        FalsePositives += 1
    elif predictions[i] == 'n' and isSentenceMetaphor[i] == 'n':
        TrueNegatives += 1
    elif predictions[i] == 'n' and isSentenceMetaphor[i] == 'y':
        FalseNegatives += 1

#Disregards unknown classifications
Positives = TruePositives + FalseNegatives #Ground truth
Negatives = TrueNegatives + FalsePositives #Ground truth

print("Positives: " + str(Positives))
print("Negatives: " + str(Negatives))
print("Predicted positives: " + str(PredictedPositives))
print("Predicted negatives: " + str(PredictedNegatives))
print("TP: " + str(TruePositives))
print("FP: " + str(FalsePositives))
print("TN: " + str(TrueNegatives))
print("FN: " + str(FalseNegatives))
# Out:
# Positives: 358
# Negatives: 322
# Predicted positives: 617
# Predicted negatives: 63
# TP: 326
# FP: 291
# TN: 31
# FN: 32

# %%
accuracy = (TruePositives + TrueNegatives) / (Positives + Negatives)
print(accuracy)
precision = TruePositives / (TruePositives + FalsePositives)
print(precision)
recall = TruePositives / (TruePositives + FalseNegatives)
print(recall)
# Out:
# 0.525
# 0.5283630470016207
# 0.9106145251396648
